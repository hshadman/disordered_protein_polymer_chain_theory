# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from __future__ import print_function
import seaborn as sns
from scipy.optimize import curve_fit
from scipy.stats import probplot,shapiro
from scipy.interpolate import make_interp_spline
import os
# Out:
# /public/apps/python/3.7.0/lib/python3.7/site-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
#protamine details
#need to remove frames and simulations that are not necessary
#only show equilibrated part
#this is for salmon
salmon_rg = pd.read_csv("~/protamine_simulation/jupyter_nb/salmon_rg.csv").iloc[:,:3]
salmon_ree = pd.read_csv("~/protamine_simulation/jupyter_nb/salmon_ree.csv")
salmon_rg_ree=pd.concat([salmon_rg,salmon_ree['Ree']],axis=1)
salmon_rg_ree=salmon_rg_ree[salmon_rg_ree.sim!=2]
salmon_rg_ree=salmon_rg_ree[salmon_rg_ree.sim!=11]
#this step is because some salmon simulations have more than 200ns
temp_df=salmon_rg_ree.copy()
for sim in temp_df.sim.unique():
    n=temp_df[temp_df.sim==sim].frames.max()-100000
    if n>0:
        temp_df.drop(temp_df[temp_df.sim==sim].tail(n).index,inplace=True)
salmon_rg_ree=temp_df.copy()
del temp_df
#this step is taking last 40000 frames i.e. equilibrated portion
blank_df = pd.DataFrame()
for sim in salmon_rg_ree.sim.unique():
    temp_df = salmon_rg_ree[salmon_rg_ree.sim==sim].iloc[-40000:,:]
    blank_df = blank_df.append(temp_df)
salmon_rg_ree = blank_df.copy()
del blank_df
del temp_df
del salmon_rg, salmon_ree

#need to remove frames and simulations that are not necessary
#only show equilibrated part
#this is for p1
p1_rg = pd.read_csv("~/protamine_simulation/jupyter_nb/p1_rg.csv")
p1_ree = pd.read_csv("~/protamine_simulation/jupyter_nb/p1_ree.csv")
p1_rg_ree=pd.concat([p1_rg,p1_ree['Ree']],axis=1)
p1_rg_ree=p1_rg_ree[p1_rg_ree.sim!=15]
p1_rg_ree=p1_rg_ree[p1_rg_ree.sim!=13]
blank_df = pd.DataFrame()
for sim in p1_rg_ree.sim.unique():
    temp_df = p1_rg_ree[p1_rg_ree.sim==sim].iloc[-40000:,:]
    blank_df = blank_df.append(temp_df)
p1_rg_ree = blank_df.copy()
del blank_df
del temp_df
del p1_rg, p1_ree

#need to remove frames and simulations that are not necessary
#only show equilibrated part
#this is for bull
bull_rg = pd.read_csv("~/protamine_simulation/jupyter_nb/bull_Rg_master_out.csv")
bull_ree = pd.read_csv("~/protamine_simulation/jupyter_nb/bull_Ree_master_out.csv")
bull_rg_ree=pd.concat([bull_rg,bull_ree['Ree']],axis=1)
bull_rg_ree=bull_rg_ree[bull_rg_ree.sim!=14]
bull_rg_ree=bull_rg_ree[bull_rg_ree.sim!=15]
blank_df = pd.DataFrame()
for sim in bull_rg_ree.sim.unique():
    temp_df = bull_rg_ree[bull_rg_ree.sim==sim].iloc[-40000:,:]
    blank_df = blank_df.append(temp_df)
bull_rg_ree = blank_df.copy()
del blank_df
del temp_df
del bull_rg, bull_ree

# %%
#protamine details
salmon_rg_ree_ratheatmap=salmon_rg_ree.copy()
salmon_rg_ree_ratheatmap['ratio']=salmon_rg_ree_ratheatmap.Ree.values**2/salmon_rg_ree_ratheatmap.Rg.values**2
salmon_rg_ree_ratheatmap
# Out:
#          frames  sim       Rg      Ree     ratio
# 60000     60001    1  26.1041  81.1896  9.673494
# 60001     60002    1  25.8683  80.1119  9.590876
# 60002     60003    1  25.9168  80.0378  9.537346
# 60003     60004    1  25.9136  79.9973  9.530050
# 60004     60005    1  25.9379  80.6699  9.672827
# ...         ...  ...      ...      ...       ...
# 1532516   99996   15  18.5986  48.8629  6.902366
# 1532517   99997   15  18.6897  48.1446  6.635757
# 1532518   99998   15  18.7345  50.0248  7.129950
# 1532519   99999   15  18.7678  50.5317  7.249384
# 1532520  100000   15  18.8159  49.5442  6.933231
#
# [520000 rows x 5 columns]

# %%
#protamine details
p1_rg_ree_ratheatmap=p1_rg_ree.copy()
p1_rg_ree_ratheatmap['ratio']=p1_rg_ree_ratheatmap.Ree.values**2/p1_rg_ree_ratheatmap.Rg.values**2
p1_rg_ree_ratheatmap
# Out:
#          frames  sim       Rg      Ree     ratio
# 60000     60001    1  28.1333  70.9610  6.362065
# 60001     60002    1  28.0252  71.5204  6.512720
# 60002     60003    1  28.0709  70.5204  6.311271
# 60003     60004    1  27.8865  69.2119  6.159898
# 60004     60005    1  27.9361  69.9112  6.262705
# ...         ...  ...      ...      ...       ...
# 1399995   99996   14  23.9297  69.6266  8.465953
# 1399996   99997   14  23.8227  69.1996  8.437722
# 1399997   99998   14  23.6595  68.5624  8.397710
# 1399998   99999   14  23.7770  69.0513  8.433922
# 1399999  100000   14  23.7506  67.9383  8.182390
#
# [520000 rows x 5 columns]

# %%
#protamine details
bull_rg_ree_ratheatmap=bull_rg_ree.copy()
bull_rg_ree_ratheatmap['ratio']=bull_rg_ree_ratheatmap.Ree.values**2/bull_rg_ree_ratheatmap.Rg.values**2
bull_rg_ree_ratheatmap
# Out:
#          frames  sim       Rg      Ree     ratio
# 60000     60001    1  24.4750  55.0058  5.050933
# 60001     60002    1  24.5678  56.4126  5.272538
# 60002     60003    1  24.5493  56.1438  5.230285
# 60003     60004    1  24.8113  56.7690  5.235082
# 60004     60005    1  25.0404  57.1523  5.209366
# ...         ...  ...      ...      ...       ...
# 1299995   99996   13  25.9520  62.3499  5.772047
# 1299996   99997   13  25.9814  62.1708  5.725953
# 1299997   99998   13  25.8608  61.9394  5.736541
# 1299998   99999   13  25.8253  62.1201  5.785935
# 1299999  100000   13  25.7948  62.2436  5.822709
#
# [520000 rows x 5 columns]

# %%
# #BE CAREFUL about changing working directory on this code
# os.chdir('../')
# chain_length_filenames=[]
# chain_lengths=[]
# for file in os.listdir():
#     if file.split('_')[0]=='chain':
#         chain_length_filenames.append(file)
#         chain_lengths.append(int(file.split('_')[2]))
# os.chdir('summary_chain_lengths_epas/')

# paths=[]
# for i in chain_length_filenames:
#     os.chdir('../'+str(i))
#     for file in os.listdir():
#         if file.split('_')[0]=='epas':
#             os.chdir(file)
#             paths.append(os.getcwd())
#             os.chdir('../')
#     os.chdir('../summary_chain_lengths_epas/')

# %%
# for file in paths:
#     print('chain_length= ',file.split('/')[6].split('_')[2])
#     print('epas= ',file.split('/')[7].split('_')[1])
#     print(open(file+'/44rep.input','r').read())
#     head = [next(open(file+'/initial.dat','r')) for x in range(1)]
#     print('check epas= ',head[0].split(' ')[3],'\n')
# Out:
# chain_length=  150
# epas=  -0.05
# initial.dat
# out.dat
# 30000
# 25000
# 10
#
# check epas=  -0.0500000
#
# chain_length=  150
# epas=  -0.2
# initial.dat
# out.dat
# 30000
# 25000
# 10
#
# check epas=  -0.2000000
#
# chain_length=  150
# epas=  0.3
# initial.dat
# out.dat
# 30000
# 25000
# 10
#
# check epas=  0.30000000
#
# chain_length=  150
# epas=  0
# initial.dat
# out.dat
# 30000
# 25000
# 10
#
# check epas=  0.00000000
#
# chain_length=  150
# epas=  0.1
# initial.dat
# out.dat
# 30000
# 25000
# 10
#
# check epas=  0.10000000
#
# chain_length=  150
# epas=  0.05
# initial.dat
# out.dat
# 30000
# 25000
# 10
#
# check epas=  0.05000000
#
# chain_length=  150
# epas=  0.2
# initial.dat
# out.dat
# 30000
# 25000
# 10
#
# check epas=  0.20000000
#
# chain_length=  150
# epas=  0.8
# initial.dat
# out.dat
# 30000
# 40000
# 10
#
# check epas=
#
# chain_length=  150
# epas=  -0.1
# initial.dat
# out.dat
# 30000
# 25000
# 10
#
# check epas=  -0.1000000
#
# chain_length=  150
# epas=  0.7
# initial.dat
# out.dat
# 30000
# 25000
# 10
#
# check epas=  0.70000000
#
# chain_length=  150
# epas=  -0.15
# initial.dat
# out.dat
# 30000
# 25000
# 10
#
# check epas=  -0.1500000
#
# chain_length=  150
# epas=  0.5
# initial.dat
# out.dat
# 30000
# 25000
# 10
#
# check epas=  0.50000000
#
# chain_length=  150
# epas=  0.35
# initial.dat
# out.dat
# 30000
# 25000
# 10
#
# check epas=  0.35000000
#
# chain_length=  150
# epas=  0.6
# initial.dat
# out.dat
# 30000
# 25000
# 10
#
# check epas=  0.60000000
#
# chain_length=  150
# epas=  0.25
# initial.dat
# out.dat
# 30000
# 25000
# 10
#
# check epas=  0.25000000
#
# chain_length=  150
# epas=  0.4
# initial.dat
# out.dat
# 30000
# 25000
# 10
#
# check epas=  0.40000000
#
# chain_length=  150
# epas=  0.15
# initial.dat
# out.dat
# 30000
# 25000
# 10
#
# check epas=  0.15000000
#
# chain_length=  75
# epas=  -0.05
# initial.dat
# out.dat
# 30000
# 25000
# 10
#
# check epas=  -0.0500000
#
# chain_length=  75
# epas=  -0.2
# initial.dat
# out.dat
# 30000
# 25000
# 10
#
# check epas=  -0.2000000
#
# chain_length=  75
# epas=  0.3
# initial.dat
# out.dat
# 30000
# 25000
# 10
#
# check epas=  0.30000000
#
# chain_length=  75
# epas=  0
# initial.dat
# out.dat
# 30000
# 25000
# 10
#
# check epas=  0.00000000
#
# chain_length=  75
# epas=  0.1
# initial.dat
# out.dat
# 30000
# 25000
# 10
#
# check epas=  0.10000000
#
# chain_length=  75
# epas=  0.05
# initial.dat
# out.dat
# 30000
# 25000
# 10
#
# check epas=  0.05000000
#
# chain_length=  75
# epas=  0.2
# initial.dat
# out.dat
# 30000
# 25000
# 10
#
# check epas=  0.20000000
#
# chain_length=  75
# epas=  0.8
# initial.dat
# out.dat
# 30000
# 25000
# 10
#
# check epas=  0.80000000
#
# chain_length=  75
# epas=  -0.1
# initial.dat
# out.dat
# 30000
# 25000
# 10
#
# check epas=  -0.1000000
#
# chain_length=  75
# epas=  0.7
# initial.dat
# out.dat
# 30000
# 25000
# 10
#
# check epas=  0.70000000
#
# chain_length=  75
# epas=  -0.15
# initial.dat
# out.dat
# 30000
# 25000
# 10
#
# check epas=  -0.1500000
#
# chain_length=  75
# epas=  0.5
# initial.dat
# out.dat
# 30000
# 25000
# 10
#
# check epas=  0.50000000
#
# chain_length=  75
# epas=  0.35
# initial.dat
# out.dat
# 30000
# 25000
# 10
#
# check epas=  0.35000000
#
# chain_length=  75
# epas=  0.6
# initial.dat
# out.dat
# 30000
# 25000
# 10
#
# check epas=  0.60000000
#
# chain_length=  75
# epas=  0.25
# initial.dat
# out.dat
# 30000
# 25000
# 10
#
# check epas=  0.25000000
#
# chain_length=  75
# epas=  0.4
# initial.dat
# out.dat
# 30000
# 25000
# 10
#
# check epas=  0.40000000
#
# chain_length=  75
# epas=  0.15
# initial.dat
# out.dat
# 30000
# 25000
# 10
#
# check epas=  0.15000000
#
# chain_length=  100
# epas=  -0.05
# initial.dat
# out.dat
# 30000
# 25000
# 10
#
# check epas=  -0.0500000
#
# chain_length=  100
# epas=  -0.2
# initial.dat
# out.dat
# 30000
# 25000
# 10
#
# check epas=  -0.2000000
#
# chain_length=  100
# epas=  0.3
# initial.dat
# out.dat
# 30000
# 25000
# 10
#
# check epas=  0.30000000
#
# chain_length=  100
# epas=  0
# initial.dat
# out.dat
# 30000
# 25000
# 10
#
# check epas=  0.00000000
#
# chain_length=  100
# epas=  0.1
# initial.dat
# out.dat
# 30000
# 25000
# 10
#
# check epas=  0.10000000
#
# chain_length=  100
# epas=  0.05
# initial.dat
# out.dat
# 30000
# 25000
# 10
#
# check epas=  0.05000000
#
# chain_length=  100
# epas=  0.2
# initial.dat
# out.dat
# 30000
# 25000
# 10
#
# check epas=  0.20000000
#
# chain_length=  100
# epas=  0.8
# initial.dat
# out.dat
# 30000
# 25000
# 10
#
# check epas=  0.80000000
#
# chain_length=  100
# epas=  -0.1
# initial.dat
# out.dat
# 30000
# 25000
# 10
#
# check epas=  -0.1000000
#
# chain_length=  100
# epas=  0.7
# initial.dat
# out.dat
# 30000
# 25000
# 10
#
# check epas=  0.70000000
#
# chain_length=  100
# epas=  -0.15
# initial.dat
# out.dat
# 30000
# 25000
# 10
#
# check epas=  -0.15000000
#
# chain_length=  100
# epas=  0.5
# initial.dat
# out.dat
# 30000
# 25000
# 10
#
# check epas=  0.50000000
#
# chain_length=  100
# epas=  0.35
# initial.dat
# out.dat
# 30000
# 25000
# 10
#
# check epas=  0.35000000
#
# chain_length=  100
# epas=  0.6
# initial.dat
# out.dat
# 30000
# 25000
# 10
#
# check epas=  0.60000000
#
# chain_length=  100
# epas=  0.25
# initial.dat
# out.dat
# 30000
# 25000
# 10
#
# check epas=  0.25000000
#
# chain_length=  100
# epas=  0.4
# initial.dat
# out.dat
# 30000
# 25000
# 10
#
# check epas=  0.40000000
#
# chain_length=  100
# epas=  0.15
# initial.dat
# out.dat
# 30000
# 25000
# 10
#
# check epas=  0.15000000
#
# chain_length=  25
# epas=  -0.05
# initial.dat
# out.dat
# 30000
# 25000
# 10
#
# check epas=  -0.0500000
#
# chain_length=  25
# epas=  -0.2
# initial.dat
# out.dat
# 30000
# 25000
# 10
#
# check epas=  -0.20000000
#
# chain_length=  25
# epas=  0.3
# initial.dat
# out.dat
# 30000
# 25000
# 10
#
# check epas=  0.30000000
#
# chain_length=  25
# epas=  0
# initial.dat
# out.dat
# 30000
# 25000
# 10
#
# check epas=  0.00000000
#
# chain_length=  25
# epas=  0.1
# initial.dat
# out.dat
# 30000
# 25000
# 10
#
# check epas=  0.10000000
#
# chain_length=  25
# epas=  0.05
# initial.dat
# out.dat
# 30000
# 25000
# 10
#
# check epas=  0.05000000
#
# chain_length=  25
# epas=  0.2
# initial.dat
# out.dat
# 30000
# 25000
# 10
#
# check epas=  0.20000000
#
# chain_length=  25
# epas=  0.8
# initial.dat
# out.dat
# 30000
# 25000
# 10
#
# check epas=  0.80000000
#
# chain_length=  25
# epas=  -0.1
# initial.dat
# out.dat
# 30000
# 25000
# 10
#
# check epas=  -0.1000000
#
# chain_length=  25
# epas=  0.7
# initial.dat
# out.dat
# 30000
# 25000
# 10
#
# check epas=
#
# chain_length=  25
# epas=  -0.15
# initial.dat
# out.dat
# 30000
# 25000
# 10
#
# check epas=  -0.15000000
#
# chain_length=  25
# epas=  0.5
# initial.dat
# out.dat
# 30000
# 25000
# 10
#
# check epas=  0.50000000
#
# chain_length=  25
# epas=  0.35
# initial.dat
# out.dat
# 30000
# 25000
# 10
#
# check epas=  0.35000000
#
# chain_length=  25
# epas=  0.6
# initial.dat
# out.dat
# 30000
# 25000
# 10
#
# check epas=  0.60000000
#
# chain_length=  25
# epas=  0.25
# initial.dat
# out.dat
# 30000
# 25000
# 10
#
# check epas=  0.25000000
#
# chain_length=  25
# epas=  0.4
# initial.dat
# out.dat
# 30000
# 25000
# 10
#
# check epas=  0.40000000
#
# chain_length=  25
# epas=  0.15
# initial.dat
# out.dat
# 30000
# 25000
# 10
#
# check epas=  0.15000000
#
# chain_length=  125
# epas=  -0.05
# initial.dat
# out.dat
# 30000
# 25000
# 10
#
# check epas=  -0.0500000
#
# chain_length=  125
# epas=  -0.2
# initial.dat
# out.dat
# 30000
# 25000
# 10
#
# check epas=  -0.2000000
#
# chain_length=  125
# epas=  0.3
# initial.dat
# out.dat
# 30000
# 25000
# 10
#
# check epas=  0.30000000
#
# chain_length=  125
# epas=  0
# initial.dat
# out.dat
# 30000
# 25000
# 10
#
# check epas=  0.00000000
#
# chain_length=  125
# epas=  0.1
# initial.dat
# out.dat
# 30000
# 25000
# 10
#
# check epas=  0.10000000
#
# chain_length=  125
# epas=  0.05
# initial.dat
# out.dat
# 30000
# 25000
# 10
#
# check epas=  0.05000000
#
# chain_length=  125
# epas=  0.2
# initial.dat
# out.dat
# 30000
# 25000
# 10
#
# check epas=  0.20000000
#
# chain_length=  125
# epas=  0.8
# initial.dat
# out.dat
# 30000
# 25000
# 10
#
# check epas=  0.80000000
#
# chain_length=  125
# epas=  -0.1
# initial.dat
# out.dat
# 30000
# 25000
# 10
#
# check epas=  -0.1000000
#
# chain_length=  125
# epas=  0.7
# initial.dat
# out.dat
# 30000
# 25000
# 10
#
# check epas=  0.70000000
#
# chain_length=  125
# epas=  -0.15
# initial.dat
# out.dat
# 30000
# 25000
# 10
#
# check epas=  -0.1500000
#
# chain_length=  125
# epas=  0.5
# initial.dat
# out.dat
# 30000
# 25000
# 10
#
# check epas=  0.50000000
#
# chain_length=  125
# epas=  0.35
# initial.dat
# out.dat
# 30000
# 25000
# 10
#
# check epas=  0.35000000
#
# chain_length=  125
# epas=  0.6
# initial.dat
# out.dat
# 30000
# 25000
# 10
#
# check epas=  0.60000000
#
# chain_length=  125
# epas=  0.25
# initial.dat
# out.dat
# 30000
# 25000
# 10
#
# check epas=  0.25000000
#
# chain_length=  125
# epas=  0.4
# initial.dat
# out.dat
# 30000
# 25000
# 10
#
# check epas=  0.40000000
#
# chain_length=  125
# epas=  0.15
# initial.dat
# out.dat
# 30000
# 25000
# 10
#
# check epas=  0.15000000
#
# chain_length=  50
# epas=  -0.05
# initial.dat
# out.dat
# 30000
# 25000
# 10
#
# check epas=  -0.0500000
#
# chain_length=  50
# epas=  -0.2
# initial.dat
# out.dat
# 30000
# 25000
# 10
#
# check epas=  -0.2000000
#
# chain_length=  50
# epas=  0.3
# initial.dat
# out.dat
# 30000
# 25000
# 10
#
# check epas=  0.30000000
#
# chain_length=  50
# epas=  0
# initial.dat
# out.dat
# 30000
# 25000
# 10
#
# check epas=  0.00000000
#
# chain_length=  50
# epas=  0.1
# initial.dat
# out.dat
# 30000
# 25000
# 10
#
# check epas=  0.10000000
#
# chain_length=  50
# epas=  0.05
# initial.dat
# out.dat
# 30000
# 25000
# 10
#
# check epas=  0.05000000
#
# chain_length=  50
# epas=  0.2
# initial.dat
# out.dat
# 30000
# 25000
# 10
#
# check epas=  0.20000000
#
# chain_length=  50
# epas=  0.8
# initial.dat
# out.dat
# 30000
# 25000
# 10
#
# check epas=  0.80000000
#
# chain_length=  50
# epas=  -0.1
# initial.dat
# out.dat
# 30000
# 25000
# 10
#
# check epas=  -0.1000000
#
# chain_length=  50
# epas=  0.7
# initial.dat
# out.dat
# 30000
# 25000
# 10
#
# check epas=  0.70000000
#
# chain_length=  50
# epas=  -0.15
# initial.dat
# out.dat
# 30000
# 25000
# 10
#
# check epas=  -0.1500000
#
# chain_length=  50
# epas=  0.5
# initial.dat
# out.dat
# 30000
# 25000
# 10
#
# check epas=  0.50000000
#
# chain_length=  50
# epas=  0.35
# initial.dat
# out.dat
# 30000
# 25000
# 10
#
# check epas=  0.35000000
#
# chain_length=  50
# epas=  0.6
# initial.dat
# out.dat
# 30000
# 25000
# 10
#
# check epas=  0.60000000
#
# chain_length=  50
# epas=  0.25
# initial.dat
# out.dat
# 30000
# 25000
# 10
#
# check epas=  0.25000000
#
# chain_length=  50
# epas=  0.4
# initial.dat
# out.dat
# 30000
# 25000
# 10
#
# check epas=  0.40000000
#
# chain_length=  50
# epas=  0.15
# initial.dat
# out.dat
# 30000
# 25000
# 10
#
# check epas=  0.15000000

# %%
#BE CAREFUL with working directory for this first part of code
#-------
os.chdir('../')
chain_lengths=[]
for file in os.listdir():
    if file.split('_')[0]=='chain':
        chain_lengths.append(int(file.split('_')[2]))
os.chdir('summary_chain_lengths_epas/')
#--------
folders=[]
chain_lengths=sorted(chain_lengths)
for i in chain_lengths:
    folders.append('../chain_length_'+str(i)+'/varying_epas_chain_length_'+str(i)+'_master_out.csv')
j=0
for file in folders:
    test=pd.read_csv(file)
    test['Rend2']=test.Rendx+test.Rendy+test.Rendz
    test['Rg2']=test.Rgx+test.Rgy+test.Rgz
    test['ratio']=test.Rend2.values/test.Rg2.values
    test['asphericity']=test.Rgx.values-(0.5*(test.Rgy.values+test.Rgz.values))
    test['acylindricity']=test.Rgy.values-test.Rgz.values
    test['RSA']=((test.asphericity.values**2+(0.75*test.acylindricity.values**2))/(test.Rg2.values)**2)**0.5

    epas_considered = test.epas.unique()
    blank_df = pd.DataFrame()
    for epas in test.epas.unique():
        if epas in epas_considered:
            frames_number=len(test[test.epas==epas].index)
            equil_frames=int(0.90*frames_number)
            temp_df = test[test.epas==epas].iloc[-equil_frames:,:]
            blank_df = blank_df.append(temp_df)
    equil_test=blank_df.copy()
    equil_test=equil_test.drop(['frames','econf'],axis=1)
    if j==0:
        equil_chain_rg_ree=equil_test.copy()
        for epas_val in equil_test.epas.unique():
            if epas_val==equil_test.epas.unique()[0]:
                running_df=pd.DataFrame(data=equil_test[equil_test.epas==epas_val].mean(axis=0)).T
            elif epas_val!=equil_test.epas.unique()[0]:
                running_df=running_df.append(pd.DataFrame(data=equil_test[equil_test.epas==epas_val].mean(axis=0)).T)            
        summary_df=running_df.copy()
    else:
        equil_chain_rg_ree=equil_chain_rg_ree.append(equil_test)
        for epas_val in equil_test.epas.unique():
            if epas_val==equil_test.epas.unique()[0]:
                running_df=pd.DataFrame(data=equil_test[equil_test.epas==epas_val].mean(axis=0)).T
            elif epas_val!=equil_test.epas.unique()[0]:
                running_df=running_df.append(pd.DataFrame(data=equil_test[equil_test.epas==epas_val].mean(axis=0)).T)            
        summary_df=pd.concat([summary_df,running_df],axis=0)    
    del blank_df, temp_df, test, equil_test    
    j+=1
del running_df
summary_df=summary_df.round({'epas':2})
equil_chain_rg_ree=equil_chain_rg_ree.round({'epas':2})

# %%
#summary_df.to_excel('summary_varying_epas_chain_length.xlsx')

# %%
fig,ax=plt.subplots(figsize=(10,8))
v_line=0.16
for chain_length in summary_df.chain_length.unique():
    ax.scatter(summary_df[summary_df.chain_length==chain_length].epas,
             summary_df[summary_df.chain_length==chain_length].Rg2/chain_length,
              s=80)
    x=np.array(summary_df[summary_df.chain_length==chain_length].epas)
    y=np.array(summary_df[summary_df.chain_length==chain_length].Rg2/chain_length)
    x, y = zip(*sorted(zip(x, y)))
    X_Y_Spline = make_interp_spline(x, y)
    X_ = np.linspace(min(x), max(x), 500)
    Y_ = X_Y_Spline(X_)
    plt.plot(X_, Y_,label='Chain_length = '+str(chain_length))

plt.legend(fontsize=22)
plt.setp(ax.get_yticklabels(), fontsize=20)
plt.setp(ax.get_xticklabels(), fontsize=20)
plt.xlabel('epas',fontsize=22)
plt.ylabel('Rg2/N',fontsize=22)
plt.axvline(v_line,ymin=0.1,ymax=0.9)
plt.text(0.18,0.2,'x= ~'+str(v_line),fontsize=20,transform=ax.transAxes)
# Out:
# Text(0.18, 0.2, 'x= ~0.16')

# %%
fig,ax=plt.subplots(figsize=(10,8))
v_line=0.3
for chain_length in summary_df.chain_length.unique():
    ax.scatter(summary_df[summary_df.chain_length==chain_length].epas,
             summary_df[summary_df.chain_length==chain_length].Rg2,
              s=80)
    x=np.array(summary_df[summary_df.chain_length==chain_length].epas)
    y=np.array(summary_df[summary_df.chain_length==chain_length].Rg2)
    x, y = zip(*sorted(zip(x, y)))
    X_Y_Spline = make_interp_spline(x, y)
    X_ = np.linspace(min(x), max(x), 500)
    Y_ = X_Y_Spline(X_)
    plt.plot(X_, Y_,label='Chain_length = '+str(chain_length))

plt.legend(fontsize=22)
plt.setp(ax.get_yticklabels(), fontsize=20)
plt.setp(ax.get_xticklabels(), fontsize=20)
plt.xlabel('epas',fontsize=22)
plt.ylabel('Rg2',fontsize=22)
plt.axvline(v_line,ymin=0.0,ymax=80)
#plt.text(0.18,0.2,'x= ~'+str(v_line),fontsize=20,transform=ax.transAxes)

# %%
fig,ax=plt.subplots(figsize=(10,8))

for chain_length in summary_df.chain_length.unique():
    ax.scatter(summary_df[summary_df.chain_length==chain_length].epas,
             summary_df[summary_df.chain_length==chain_length].ratio,
              s=80)
    x=np.array(summary_df[summary_df.chain_length==chain_length].epas)
    y=np.array(summary_df[summary_df.chain_length==chain_length].ratio)
    x, y = zip(*sorted(zip(x, y)))
    X_Y_Spline = make_interp_spline(x, y)
    X_ = np.linspace(min(x), max(x), 500)
    Y_ = X_Y_Spline(X_)
    plt.plot(X_, Y_,label='Chain_length = '+str(chain_length))

plt.legend(fontsize=19)
plt.setp(ax.get_yticklabels(), fontsize=20)
plt.setp(ax.get_xticklabels(), fontsize=20)
plt.xlabel('epas',fontsize=22)
plt.ylabel('Shape Ratio <Ree^2/Rg^2>',fontsize=22)
# Out:
# Text(0, 0.5, 'Shape Ratio <Ree^2/Rg^2>')

# %%
fig,ax=plt.subplots(figsize=(10,8))

for chain_length in summary_df.chain_length.unique():
    ax.scatter(summary_df[summary_df.chain_length==chain_length].epas,
             summary_df[summary_df.chain_length==chain_length].RSA,
              s=80)
    x=np.array(summary_df[summary_df.chain_length==chain_length].epas)
    y=np.array(summary_df[summary_df.chain_length==chain_length].RSA)
    x, y = zip(*sorted(zip(x, y)))
    X_Y_Spline = make_interp_spline(x, y)
    X_ = np.linspace(min(x), max(x), 500)
    Y_ = X_Y_Spline(X_)
    plt.plot(X_, Y_,label='Chain_length = '+str(chain_length))

plt.legend(fontsize=17,loc='upper right')
plt.setp(ax.get_yticklabels(), fontsize=20)
plt.setp(ax.get_xticklabels(), fontsize=20)
plt.xlabel('epas',fontsize=22)
plt.ylabel('RSA',fontsize=22)
# Out:
# Text(0, 0.5, 'RSA')

# %%
fig,ax=plt.subplots(figsize=(10,8))

for chain_length in summary_df.chain_length.unique():
    ax.scatter(summary_df[summary_df.chain_length==chain_length].epas,
             summary_df[summary_df.chain_length==chain_length].asphericity,
              s=80)
    x=np.array(summary_df[summary_df.chain_length==chain_length].epas)
    y=np.array(summary_df[summary_df.chain_length==chain_length].asphericity)
    x, y = zip(*sorted(zip(x, y)))
    X_Y_Spline = make_interp_spline(x, y)
    X_ = np.linspace(min(x), max(x), 500)
    Y_ = X_Y_Spline(X_)
    plt.plot(X_, Y_,label='Chain_length = '+str(chain_length))

plt.legend(fontsize=19,loc='upper right')
plt.setp(ax.get_yticklabels(), fontsize=20)
plt.setp(ax.get_xticklabels(), fontsize=20)
plt.xlabel('epas',fontsize=22)
plt.ylabel('asphericity',fontsize=22)
# Out:
# Text(0, 0.5, 'asphericity')

# %%
fig,ax=plt.subplots(figsize=(15,12))

for chain_length in summary_df.chain_length.unique():
    x=summary_df[summary_df.chain_length==chain_length].ratio
    y=summary_df[summary_df.chain_length==chain_length].RSA
    ax.scatter(x,
    y,
    s=80,label='chain_length= '+str(chain_length))
    ax.plot(x,
            np.poly1d(np.polyfit(x,
                                 y, 1))(x))
ax.text(0.30,0.95,'Each point represents mean at a single epas value',transform=ax.transAxes,fontsize=17)
ax.text(0.30,0.90,'All epas values represented',transform=ax.transAxes,fontsize=17)
plt.legend(fontsize=17,loc='upper left')
plt.setp(ax.get_yticklabels(), fontsize=20)
plt.setp(ax.get_xticklabels(), fontsize=20)
plt.xlabel('ratio <Ree^2/Rg^2>',fontsize=22)
plt.ylabel('RSA',fontsize=22)
# Out:
# Text(0, 0.5, 'RSA')

# %%
#use i because there are i bonds
fig,ax = plt.subplots(figsize=(9,6))
chain_length_skip=25
every_ith_frame=1
for i in equil_chain_rg_ree.chain_length.unique():
    if i!=chain_length_skip:
        ax.scatter(np.log(i-1),np.log((equil_chain_rg_ree[(equil_chain_rg_ree.chain_length==i) & (equil_chain_rg_ree.epas==0)].iloc[::every_ith_frame,:].Rg2.values.mean())**0.5),
                label='Chain_length= '+str(i))
        print(np.log(i-1),np.log((equil_chain_rg_ree[(equil_chain_rg_ree.chain_length==i) & (equil_chain_rg_ree.epas==0)].iloc[::every_ith_frame,:].Rg2.values.mean())**0.5))
ax.legend(fontsize=15,loc='lower right')
ax.set_xlabel('ln(chain_length)',fontsize=22)
ax.set_ylabel('ln(Rg)',fontsize=22)
x=np.array([np.log(i-1) for i in equil_chain_rg_ree.chain_length.unique() if i!=chain_length_skip])
y=np.array([np.log((equil_chain_rg_ree[(equil_chain_rg_ree.chain_length==i) & (equil_chain_rg_ree.epas==0)].iloc[::every_ith_frame,:].Rg2.values.mean())**0.5) for i in equil_chain_rg_ree.chain_length.unique() if i!=chain_length_skip])
a, b = np.polyfit(x, y, 1)
ax.plot(x, a*x+b, color='steelblue', linestyle='--', linewidth=2)
ax.text(0.20,0.96,'Every '+str(every_ith_frame)+'th frame',fontsize=15,horizontalAlignment='center',transform=ax.transAxes)
#plt.set_title('')
ax.text(4.0, 1.8, 'y = ' + '{:.3f}'.format(b) + ' + {:.3f}'.format(a) + 'x', size=14,fontsize=15)
ax.text(0.1,0.9,'epas=0',transform=ax.transAxes,fontsize=20)
plt.setp(ax.get_yticklabels(), fontsize=20)
plt.setp(ax.get_xticklabels(), fontsize=20)
plt.tight_layout()
# Out:
# 3.8918202981106265 1.4420882840061686
# 4.30406509320417 1.6907433902655906
# 4.59511985013459 1.863337175193901
# 4.820281565605037 1.9974143488113725
# 5.003946305945459 2.1074484718325257
# /public/apps/python/3.7.0/lib/python3.7/site-packages/ipykernel_launcher.py:17: MatplotlibDeprecationWarning: Case-insensitive properties were deprecated in 3.3 and support will be removed two minor releases later

# %%
#use i because there are i bonds
fig,ax = plt.subplots(figsize=(9,6))
chain_length_skip=25
every_ith_frame=1
epas_value=0.2
for i in equil_chain_rg_ree.chain_length.unique():
    if i!=chain_length_skip:
        ax.scatter(np.log(i-1),np.log((equil_chain_rg_ree[(equil_chain_rg_ree.chain_length==i) & (equil_chain_rg_ree.epas==epas_value)].iloc[::every_ith_frame,:].Rg2.values.mean())**0.5),
                label='Chain_length= '+str(i))
        print(np.log(i-1),np.log((equil_chain_rg_ree[(equil_chain_rg_ree.chain_length==i) & (equil_chain_rg_ree.epas==epas_value)].iloc[::every_ith_frame,:].Rg2.values.mean())**0.5))
ax.legend(fontsize=15,loc='lower right')
ax.set_xlabel('ln(chain_length)',fontsize=22)
ax.set_ylabel('ln(Rg)',fontsize=22)
x=np.array([np.log(i-1) for i in equil_chain_rg_ree.chain_length.unique() if i!=chain_length_skip])
y=np.array([np.log((equil_chain_rg_ree[(equil_chain_rg_ree.chain_length==i) & (equil_chain_rg_ree.epas==epas_value)].iloc[::every_ith_frame,:].Rg2.values.mean())**0.5) for i in equil_chain_rg_ree.chain_length.unique() if i!=chain_length_skip])
a, b = np.polyfit(x, y, 1)
ax.plot(x, a*x+b, color='steelblue', linestyle='--', linewidth=2)
ax.text(0.20,0.96,'Every '+str(every_ith_frame)+'th frame',fontsize=15,horizontalAlignment='center',transform=ax.transAxes)
#plt.set_title('')
ax.text(0.1, 0.8, 'y = ' + '{:.3f}'.format(b) + ' + {:.3f}'.format(a) + 'x', size=14,fontsize=15,transform=ax.transAxes)
ax.text(0.1,0.9,f'epas={epas_value}',transform=ax.transAxes,fontsize=20)
plt.setp(ax.get_yticklabels(), fontsize=20)
plt.setp(ax.get_xticklabels(), fontsize=20)
plt.tight_layout()
# Out:
# 3.8918202981106265 1.1904667801323794
# 4.30406509320417 1.356576479560089
# 4.59511985013459 1.470539230959423
# 4.820281565605037 1.5453014425490073
# 5.003946305945459 1.5976955696891386
# /public/apps/python/3.7.0/lib/python3.7/site-packages/ipykernel_launcher.py:18: MatplotlibDeprecationWarning: Case-insensitive properties were deprecated in 3.3 and support will be removed two minor releases later

# %% [markdown]
# # above graph includes all epas, below graph epas<=0.3

# %%
fig,ax=plt.subplots(figsize=(15,12))
epas=0.3
for chain_length in summary_df.chain_length.unique():
    x=summary_df[(summary_df.chain_length==chain_length)&(summary_df.epas<=epas)].ratio
    y=summary_df[(summary_df.chain_length==chain_length)&(summary_df.epas<=epas)].RSA
    ax.scatter(x,
    y,
    s=80,label='chain_length= '+str(chain_length))
    ax.plot(x,
            np.poly1d(np.polyfit(x,
                                 y, 1))(x))
ax.text(0.30,0.95,'Each point represents mean at a single epas value',transform=ax.transAxes,fontsize=17)
ax.text(0.30,0.90,'All epas<='+str(epas),transform=ax.transAxes,fontsize=17)
plt.legend(fontsize=17,loc='upper left')
plt.setp(ax.get_yticklabels(), fontsize=20)
plt.setp(ax.get_xticklabels(), fontsize=20)
plt.xlabel('ratio',fontsize=22)
plt.ylabel('RSA',fontsize=22)
# Out:
# Text(0, 0.5, 'RSA')

# %%
epas_cutoff=0.3
testeq=equil_chain_rg_ree.copy().sort_values(by='chain_length')
fig,axs=plt.subplots(nrows=len(testeq.chain_length.unique()),
                     ncols=len(testeq.epas.unique()[testeq.epas.unique()<=epas_cutoff]),
                     figsize=(35,22),constrained_layout=True)
#plt.subplots_adjust(wspace=0.22)
subplots=axs.ravel()

j=0
for chain_length in testeq.chain_length.unique():
    for epas in testeq[testeq.chain_length==chain_length].sort_values(by='epas').epas.unique():
        if epas<=epas_cutoff:
            x=testeq[(testeq.chain_length==chain_length) & (testeq.epas==epas) ].ratio
            y=testeq[(testeq.chain_length==chain_length) & (testeq.epas==epas) ].RSA
            subplots[j].scatter(x,y,
                       s=80,label=str(j))
            subplots[j].set_ylim(testeq.RSA.min(),testeq.RSA.max())
            subplots[j].set_xlim(testeq.ratio.min(),testeq.ratio.max())
            plt.setp(subplots[j].get_yticklabels(), fontsize=16)
            plt.setp(subplots[j].get_xticklabels(), fontsize=16)
            if j==0 or j%len(testeq.epas.unique()[testeq.epas.unique()<=epas_cutoff])==0:
                subplots[j].set_ylabel('Chain Length '+str(chain_length),fontsize=22)
            if j<len(testeq.epas.unique()[testeq.epas.unique()<=epas_cutoff]):
                subplots[j].set_title('epas '+str(epas),fontsize=22)      
            j+=1
        

fig.suptitle('RSA (y-axis) vs Ratio <Ree^2/Rg^2> (x-axis)',fontsize=43)
#fig.tight_layout()

del testeq

# %%
epas_cutoff=0.3
testeq=equil_chain_rg_ree.copy().sort_values(by='chain_length')
fig,axs=plt.subplots(nrows=len(testeq.chain_length.unique()),
                     ncols=len(testeq.epas.unique()[testeq.epas.unique()>epas_cutoff]),
                     figsize=(35,22),constrained_layout=True)
#plt.subplots_adjust(wspace=0.22)
subplots=axs.ravel()

j=0
for chain_length in testeq.chain_length.unique():
    for epas in testeq[testeq.chain_length==chain_length].sort_values(by='epas').epas.unique():
        if epas>epas_cutoff:
            x=testeq[(testeq.chain_length==chain_length) & (testeq.epas==epas) ].ratio
            y=testeq[(testeq.chain_length==chain_length) & (testeq.epas==epas) ].RSA
            subplots[j].scatter(x,y,
                       s=80,label=str(j))
            subplots[j].set_ylim(testeq.RSA.min(),testeq.RSA.max())
            subplots[j].set_xlim(testeq.ratio.min(),testeq.ratio.max())
            plt.setp(subplots[j].get_yticklabels(), fontsize=16)
            plt.setp(subplots[j].get_xticklabels(), fontsize=16)
            if j==0 or j%len(testeq.epas.unique()[testeq.epas.unique()>epas_cutoff])==0:
                subplots[j].set_ylabel('Chain Length '+str(chain_length),fontsize=22)
            if j<len(testeq.epas.unique()[testeq.epas.unique()>epas_cutoff]):
                subplots[j].set_title('epas '+str(epas),fontsize=22)      
            j+=1
        

fig.suptitle('RSA (y-axis) vs Ratio <Ree^2/Rg^2> (x-axis)',fontsize=43)
#fig.tight_layout()

del testeq

# %%
epas_cutoff=0.2
testeq=equil_chain_rg_ree.copy().sort_values(by='chain_length')
# %time
# %matplotlib inline
plt.rcParams["font.weight"] = "regular"
plt.rcParams["axes.labelweight"] = "regular"
fig,ax = plt.subplots(figsize=(10,10))
scatter_markers=['d','x',4,'o','v','^','1','8','s','p','P','*','X','D',9]
j=0
for chain_length in testeq.chain_length.unique():
    for epas in testeq[testeq.chain_length==chain_length].sort_values(by='epas').epas.unique():
        if epas==epas_cutoff and chain_length in [100]:
            x=testeq[(testeq.chain_length==chain_length) & (testeq.epas==epas) ].Rg2**0.5/(testeq[(testeq.chain_length==chain_length) & (testeq.epas==epas) ].Rg2.mean()**0.5)
            y=testeq[(testeq.chain_length==chain_length) & (testeq.epas==epas) ].ratio
            ax.scatter(x,y,
                       marker=scatter_markers[j],s=40,alpha=0.6,
                       label=str(chain_length)+'_'+str(epas))
            #ax.set_ylim(testeq.ratio.min(),testeq.ratio.max())
#            ax.set_xlim(testeq.Rg2.min()**0.5,testeq.Rg2.max()**0.5)
#            ax.set_xlim(testeq.Rg2.min()**0.5,testeq.Rg2.max()**0.5)
            plt.setp(ax.get_yticklabels(), fontsize=16)
            plt.setp(ax.get_xticklabels(), fontsize=16)

            j+=1
ax.set_ylim(-1,20)
ax.set_xlim(0.3,3)
        
ax.set_xlabel('Rg/Rg_mean',fontsize=20)
ax.set_ylabel('Ratio <Ree^2/Rg^2>',fontsize=20)
ax.legend(fontsize=15)

#fig.tight_layout()

del testeq
# Out:
# CPU times: user 2 µs, sys: 1 µs, total: 3 µs
# Wall time: 5.72 µs

# %%
epas_cutoff=0.2
testeq=equil_chain_rg_ree.copy().sort_values(by='chain_length')
# %time
# %matplotlib inline
plt.rcParams["font.weight"] = "regular"
plt.rcParams["axes.labelweight"] = "regular"
fig,ax = plt.subplots(figsize=(10,10))
scatter_markers=['d','x',4,'o','v','^','1','8','s','p','P','*','X','D',9]
j=0
for chain_length in testeq.chain_length.unique():
    for epas in testeq[testeq.chain_length==chain_length].sort_values(by='epas').epas.unique():
        if epas==epas_cutoff:
            x=testeq[(testeq.chain_length==chain_length) & (testeq.epas==epas) ].Rg2**0.5/(testeq[(testeq.chain_length==chain_length) & (testeq.epas==epas) ].Rg2.mean()**0.5)
            y=testeq[(testeq.chain_length==chain_length) & (testeq.epas==epas) ].ratio
            ax.scatter(x,y,
                       marker=scatter_markers[j],s=40,alpha=0.6,
                       label=str(chain_length)+'_'+str(epas))
            #ax.set_ylim(testeq.ratio.min(),testeq.ratio.max())
#            ax.set_xlim(testeq.Rg2.min()**0.5,testeq.Rg2.max()**0.5)
#            ax.set_xlim(testeq.Rg2.min()**0.5,testeq.Rg2.max()**0.5)
            plt.setp(ax.get_yticklabels(), fontsize=16)
            plt.setp(ax.get_xticklabels(), fontsize=16)

            j+=1
ax.set_ylim(-1,20)
ax.set_xlim(0.3,3)
        
ax.set_xlabel('Rg/Rg_mean',fontsize=20)
ax.set_ylabel('Ratio <Ree^2/Rg^2>',fontsize=20)
ax.legend(fontsize=15)

#fig.tight_layout()

del testeq

# %%
epas_cutoff=0
testeq=equil_chain_rg_ree.copy().sort_values(by='chain_length')
# %time
# %matplotlib inline
plt.rcParams["font.weight"] = "regular"
plt.rcParams["axes.labelweight"] = "regular"
fig,ax = plt.subplots(figsize=(10,10))
scatter_markers=['d','x',4,'o','v','^','1','8','s','p','P','*','X','D',9]
j=0
for chain_length in testeq.chain_length.unique():
    for epas in testeq[testeq.chain_length==chain_length].sort_values(by='epas').epas.unique():
        if epas==epas_cutoff:
            x=testeq[(testeq.chain_length==chain_length) & (testeq.epas==epas) ].Rg2**0.5/(testeq[(testeq.chain_length==chain_length) & (testeq.epas==epas) ].Rg2.mean()**0.5)
            y=testeq[(testeq.chain_length==chain_length) & (testeq.epas==epas) ].ratio
            if chain_length==testeq.chain_length.unique()[len(testeq.chain_length.unique())-1]:
                ax.scatter(x,y,
                           marker=scatter_markers[3],s=40,alpha=0.6,color='blue',
                           label='SAW: All Chain Lengths')
            else:
                ax.scatter(x,y,
                           marker=scatter_markers[3],s=40,alpha=0.6,color='blue')
#            ax.set_ylim(0,25)
#            ax.set_xlim(0,3)
            plt.setp(ax.get_yticklabels(), fontsize=16)
            plt.setp(ax.get_xticklabels(), fontsize=16)

            j+=1
            
temp_sal =  salmon_rg_ree_ratheatmap.copy()
temp_p1  = p1_rg_ree_ratheatmap.copy()
temp_bull = bull_rg_ree_ratheatmap.copy()

for sim in temp_sal.sim.unique():
    if sim==temp_sal.sim.unique()[len(temp_sal.sim.unique())-1]:
        ax.scatter(salmon_rg_ree_ratheatmap[salmon_rg_ree_ratheatmap.sim==sim].iloc[::100,:].Rg.values/salmon_rg_ree_ratheatmap[salmon_rg_ree_ratheatmap.sim==sim].iloc[::100,:].Rg.mean(),
                   salmon_rg_ree_ratheatmap[salmon_rg_ree_ratheatmap.sim==sim].iloc[::100,:].ratio.values,
                   marker=scatter_markers[2],s=40,alpha=0.6,
                                          label='salmon')
    else:
        ax.scatter(salmon_rg_ree_ratheatmap[salmon_rg_ree_ratheatmap.sim==sim].iloc[::100,:].Rg.values/salmon_rg_ree_ratheatmap[salmon_rg_ree_ratheatmap.sim==sim].iloc[::100,:].Rg.mean(),
                   salmon_rg_ree_ratheatmap[salmon_rg_ree_ratheatmap.sim==sim].iloc[::100,:].ratio.values,
                   marker=scatter_markers[2],s=40,alpha=0.6)
        
for sim in temp_p1.sim.unique():
    if sim==temp_p1.sim.unique()[len(temp_p1.sim.unique())-1]:
        ax.scatter(p1_rg_ree_ratheatmap[p1_rg_ree_ratheatmap.sim==sim].iloc[::100,:].Rg.values/p1_rg_ree_ratheatmap[p1_rg_ree_ratheatmap.sim==sim].iloc[::100,:].Rg.mean(),
                   p1_rg_ree_ratheatmap[p1_rg_ree_ratheatmap.sim==sim].iloc[::100,:].ratio.values,
                   marker=scatter_markers[1],s=40,alpha=0.6,
                                          label='human P1')
    else:
        ax.scatter(p1_rg_ree_ratheatmap[p1_rg_ree_ratheatmap.sim==sim].iloc[::100,:].Rg.values/p1_rg_ree_ratheatmap[p1_rg_ree_ratheatmap.sim==sim].iloc[::100,:].Rg.mean(),
                   p1_rg_ree_ratheatmap[p1_rg_ree_ratheatmap.sim==sim].iloc[::100,:].ratio.values,
                   marker=scatter_markers[1],s=40,alpha=0.6)

for sim in temp_bull.sim.unique():
    if sim==temp_bull.sim.unique()[len(temp_bull.sim.unique())-1]:
        ax.scatter(bull_rg_ree_ratheatmap[bull_rg_ree_ratheatmap.sim==sim].iloc[::100,:].Rg.values/bull_rg_ree_ratheatmap[bull_rg_ree_ratheatmap.sim==sim].iloc[::100,:].Rg.mean(),
                   bull_rg_ree_ratheatmap[bull_rg_ree_ratheatmap.sim==sim].iloc[::100,:].ratio.values,
                   marker=scatter_markers[2],s=40,alpha=0.6,
                                          label='Bull')
    else:
        ax.scatter(bull_rg_ree_ratheatmap[bull_rg_ree_ratheatmap.sim==sim].iloc[::100,:].Rg.values/bull_rg_ree_ratheatmap[bull_rg_ree_ratheatmap.sim==sim].iloc[::100,:].Rg.mean(),
                   bull_rg_ree_ratheatmap[bull_rg_ree_ratheatmap.sim==sim].iloc[::100,:].ratio.values,
                   marker=scatter_markers[2],s=40,alpha=0.6)        
        
ax.set_xlabel('Rg/Rg_mean',fontsize=20)
ax.set_ylabel('Ratio <Ree^2/Rg^2>',fontsize=20)
ax.legend(fontsize=15)
ax.set_ylim(-1,20)
ax.set_xlim(0.3,3)

#fig.tight_layout()

del testeq, temp_p1, temp_sal, temp_bull
# Out:
# CPU times: user 2 µs, sys: 0 ns, total: 2 µs
# Wall time: 5.48 µs

# %%
#Protamine vs SAW
#salmon ratio vs Rg
# %time
# %matplotlib inline
plt.rcParams["font.weight"] = "regular"
plt.rcParams["axes.labelweight"] = "regular"
fig,ax = plt.subplots(figsize=(5,5))
temp_sal =  salmon_rg_ree_ratheatmap.copy()
scatter_markers=['d','x',4,'o','v','^','1','8','s','p','P','*','X','D',9]
for sim in temp_sal.sim.unique():
    ax.scatter(salmon_rg_ree_ratheatmap[salmon_rg_ree_ratheatmap.sim==sim].iloc[::100,:].Rg.values,
               salmon_rg_ree_ratheatmap[salmon_rg_ree_ratheatmap.sim==sim].iloc[::100,:].ratio.values,
               marker=scatter_markers[sim-1],s=4,alpha=0.6,
                                      label=str(sim))
#ax.legend(fontsize=15)
#ax.set_title('Salmon',fontsize=29)#Ratio vs Rg
ax.set_xlabel(r'$R_{g}$'+' ('+ r'$\AA$'+')',fontsize=10)
ax.set_ylabel(r'$R_{s}$',fontsize=10)
ax.set_ylim(min([salmon_rg_ree_ratheatmap.ratio.min(),p1_rg_ree_ratheatmap.ratio.min(),bull_rg_ree_ratheatmap.ratio.min()]),
            max([salmon_rg_ree_ratheatmap.ratio.max(),p1_rg_ree_ratheatmap.ratio.max(),bull_rg_ree_ratheatmap.ratio.max()]))
ax.text(12.5,1.75,'1',fontsize=10)#simulation 4, frame 77501
ax.annotate("",xy=(12.8,1.954101),xytext=(14.0674,1.954101),arrowprops=dict(arrowstyle='->'))
ax.add_patch(plt.Circle([14.0674,1.954101],0.15,linewidth=1,color='black',fill=False))
ax.text(12.5,5.72,'2',fontsize=10)# simulation 13, frame 91801
ax.annotate("",xy=(12.9,5.927344),xytext=(17.3844,5.927344),arrowprops=dict(arrowstyle='->'))
ax.add_patch(plt.Circle([17.3844,5.927344],0.15,linewidth=1,color='black',fill=False))
ax.text(26.6,2.21,'3',fontsize=10)#simulation 5, frame 90301
ax.annotate("",xy=(26.8,2.414776),xytext=(22.2148,2.414776),arrowprops=dict(arrowstyle='->'))
ax.add_patch(plt.Circle([22.2148,2.414776],0.15,linewidth=1,color='black',fill=False))
ax.text(19.9,11.0,'4',fontsize=10)#simulation 13, frame 99501
ax.annotate("",xy=(20.2131,11),xytext=(20.2131,8.719279),arrowprops=dict(arrowstyle='->'))
ax.add_patch(plt.Circle([20.2131,8.719279],0.15,linewidth=1,color='black',fill=False))
ax.text(26.7,6.51,'5',fontsize=10)#simulation 11, frame 77901
ax.annotate("",xy=(26.8,6.711931),xytext=(23.7157,6.711931),arrowprops=dict(arrowstyle='->'))
ax.add_patch(plt.Circle([23.7157,6.711931],0.15,linewidth=1,color='black',fill=False))
ax.text(26.7,4.452490,'6',fontsize=10)#simulation 8, frame 74501
ax.annotate("",xy=(26.8,4.652490),xytext=(23.8005,4.652490),arrowprops=dict(arrowstyle='->'))
ax.add_patch(plt.Circle([23.8005,4.652490],0.15,linewidth=1,color='black',fill=False))
ax.text(12.5,3.46,'7',fontsize=10)#simulation 10, frame 83901
ax.annotate("",xy=(12.8,3.664833),xytext=(16.8935,3.664833),arrowprops=dict(arrowstyle='->'))
ax.add_patch(plt.Circle([16.8935,3.664833],0.15,linewidth=1,color='black',fill=False))
ax.text(26.7,10.12,'8',fontsize=10)#simulation 8, frame 93701
ax.annotate("",xy=(26.8,10.322095),xytext=(24.7827,10.322095),arrowprops=dict(arrowstyle='->'))
ax.add_patch(plt.Circle([24.7827,10.322095],0.15,linewidth=1,color='black',fill=False))
ax.text(.9,.93,'Salmon',fontsize=10,
        horizontalalignment='center',
        transform=ax.transAxes)
#ax.set_xlim(0,201)
plt.setp(ax.get_yticklabels(), fontsize=8)
plt.setp(ax.get_xticklabels(), fontsize=8)
del temp_sal
#plt.savefig('figures_for_publication/salmon_ratio_vs_rg_combined.png',dpi=400,bbox_inches='tight')
# Out:
# CPU times: user 2 µs, sys: 1 µs, total: 3 µs
# Wall time: 6.2 µs

# %%
import plotly.express as px
test_df=equil_chain_rg_ree[(equil_chain_rg_ree.chain_length==chain_length) & (equil_chain_rg_ree.epas==epas)]
fig = px.density_heatmap(test_df, x="ratio", y="RSA",marginal_x='histogram',marginal_y='histogram',
                        nbinsx=20,nbinsy=20)
fig.show()
del test_df
# Out:
#         epas  chain_length        Rgx        Rgy        Rgz  Rendx  Rendy  \
# 93031    0.0            25   2.854400   1.142400   1.040000    1.0    9.0
# 93032    0.0            25   1.145600   0.553600   3.894400   16.0    4.0
# 93033    0.0            25   1.033600   0.902400   3.446400    9.0    0.0
# 93034    0.0            25   1.318400   0.217600   3.590400    9.0    0.0
# 93035    0.0            25   2.758400   0.921600   1.638400   36.0    0.0
# ...      ...           ...        ...        ...        ...    ...    ...
# 120035   0.0           150   9.008933  42.800000   9.446933   49.0  225.0
# 120036   0.0           150   7.538489  18.355956  21.655289    1.0    9.0
# 120037   0.0           150   4.254622  21.482489  78.635556    9.0   49.0
# 120038   0.0           150  32.216400   7.207289   9.775289  169.0   16.0
# 120039   0.0           150   9.673822  18.691956  14.845556    4.0  100.0
#
#         Rendz  Rend2         Rg2     ratio  asphericity  acylindricity  \
# 93031     4.0   14.0    5.036800  2.779543     1.763200       0.102400
# 93032    16.0   36.0    5.593600  6.435927    -1.078400      -3.340800
# 93033    25.0   34.0    5.382400  6.316885    -1.140800      -2.544000
# 93034    25.0   34.0    5.126400  6.632335    -0.585600      -3.372800
# 93035     0.0   36.0    5.318400  6.768953     1.478400      -0.716800
# ...       ...    ...         ...       ...          ...            ...
# 120035   25.0  299.0   61.255867  4.881165   -17.114533      33.353067
# 120036   49.0   59.0   47.549733  1.240806   -12.467133      -3.299333
# 120037  729.0  787.0  104.372667  7.540288   -45.804400     -57.153067
# 120038  100.0  285.0   49.198978  5.792803    23.725111      -2.568000
# 120039  121.0  225.0   43.211333  5.206967    -7.094933       3.846400
#
#              RSA
# 93031   0.350506
# 93032   0.551999
# 93033   0.460947
# 93034   0.581120
# 93035   0.301489
# ...          ...
# 120035  0.548098
# 120036  0.268989
# 120037  0.646128
# 120038  0.484342
# 120039  0.181387
#
# [162054 rows x 14 columns]

# %%
epas_cutoff=0.3
testeq=equil_chain_rg_ree.copy().sort_values(by='chain_length')
fig,axs=plt.subplots(nrows=len(testeq.chain_length.unique()),
                     ncols=len(testeq.epas.unique()[testeq.epas.unique()>epas_cutoff]),
                     figsize=(35,22),constrained_layout=True)
#plt.subplots_adjust(wspace=0.22)
subplots=axs.ravel()

j=0
for chain_length in testeq.chain_length.unique():
    for epas in testeq[testeq.chain_length==chain_length].sort_values(by='epas').epas.unique():
        if epas>epas_cutoff:
            x=testeq[(testeq.chain_length==chain_length) & (testeq.epas==epas) ].Rg2**0.5
            y=testeq[(testeq.chain_length==chain_length) & (testeq.epas==epas) ].ratio
            subplots[j].scatter(x,y,
                       s=80,label=str(j))
            subplots[j].set_ylim(testeq.ratio.min(),testeq.ratio.max())
            subplots[j].set_xlim(testeq.Rg2.min()**0.5,testeq.Rg2.max()**0.5)
            plt.setp(subplots[j].get_yticklabels(), fontsize=16)
            plt.setp(subplots[j].get_xticklabels(), fontsize=16)
            if j==0 or j%len(testeq.epas.unique()[testeq.epas.unique()>epas_cutoff])==0:
                subplots[j].set_ylabel('Chain Length '+str(chain_length),fontsize=22)
            if j<len(testeq.epas.unique()[testeq.epas.unique()>epas_cutoff]):
                subplots[j].set_title('epas '+str(epas),fontsize=22)      
            j+=1
        

fig.suptitle('Ratio <Ree^2/Rg^2> (y-axis) vs Rg (x-axis)',fontsize=43)
#fig.tight_layout()

del testeq

# %%
fig,ax=plt.subplots(figsize=(13,9))
chain_length=25
epas=0.8
every_jth_frame=1
testeq=equil_chain_rg_ree.copy()
x=testeq[(testeq.chain_length==chain_length) & (testeq.epas==epas) ][::every_jth_frame].ratio
y=testeq[(testeq.chain_length==chain_length) & (testeq.epas==epas) ][::every_jth_frame].RSA

ax.scatter(x,y,
s=80,label='chain_length, epas = '+str(chain_length)+', '+str(epas))
#ax.plot(testeq[(testeq.chain_length==chain_length) & (testeq.epas==epas) ].ratio,
#       testeq[(testeq.chain_length==chain_length) & (testeq.epas==epas) ].RSA)
ax.set_ylim(testeq.RSA.min(),testeq.RSA.max())
ax.set_xlim(testeq.ratio.min(),testeq.ratio.max())
ax.text(0.7,0.8,'Every '+str(every_jth_frame)+' snaps', transform=ax.transAxes,fontsize=20)
plt.legend(fontsize=17,loc='best')
plt.setp(ax.get_yticklabels(), fontsize=20)
plt.setp(ax.get_xticklabels(), fontsize=20)
plt.xlabel('ratio <Ree^2/Rg^2>',fontsize=22)
plt.ylabel('RSA',fontsize=22)
del testeq

# %%
import plotly.express as px
test_df=testeq[(testeq.chain_length==chain_length) & (testeq.epas==epas)]
fig = px.density_heatmap(test_df, x="ratio", y="RSA",marginal_x='histogram',marginal_y='histogram',
                        nbinsx=20,nbinsy=20)
fig.show()
del test_df
# Out:
# <div>
#
#
#             <div id="31123641-682f-4fe8-8574-08017608f10e" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("31123641-682f-4fe8-8574-08017608f10e")) {
#                     Plotly.newPlot(
#                         '31123641-682f-4fe8-8574-08017608f10e',
#                         [{"coloraxis": "coloraxis", "hoverlabel": {"namelength": 0}, "hovertemplate": "ratio=%{x}<br>RSA=%{y}<br>count=%{z}", "name": "", "nbinsx": 20, "nbinsy": 20, "type": "histogram2d", "x": [5.858803506602391, 6.607785626100042, 3.9711962421090705, 8.272530021904725, 3.2547213550520873, 6.55173801570523, 8.509593402313255, 10.117981051244504, 2.32017288853297, 9.027537496175906, 6.20935400070293, 5.902719978692939, 8.515157028154249, 1.2150326818994854, 4.034161485206311, 3.4625424701357486, 4.633026952401089, 6.799807863003386, 8.522619263865371, 9.310076279430774, 6.585990905392051, 6.1810534781993365, 8.71326630242215, 3.4172244182280886, 2.5744120021600443, 5.471919592413326, 1.676880209447747, 6.848578784800095, 8.928784653821278, 8.23429294668291, 6.2868913887156985, 8.924303066889527, 7.097964036982209, 11.404837303226394, 6.92284024477796, 9.420545366404328, 2.902047767753331, 2.018174921461385, 2.9294662221215164, 9.99051260673317, 3.4211313153165643, 6.6127758669147045, 3.1366656856518844, 7.919082998714811, 7.828448574981995, 4.106568069782639, 4.346452981758922, 9.289480371592015, 1.2267019185012213, 4.217751994533553, 1.565289984463047, 3.084503853126785, 7.276154607087642, 3.3176465724542332, 11.669950008107731, 9.691211619361336, 6.212528522203442, 2.225224532240164, 7.562681525902722, 8.596083321065276, 3.7086427598119607, 3.8570407194792047, 1.4021101852136868, 3.6529353058265017, 9.257302551849937, 9.871425347487815, 5.912197715766969, 10.312168858148071, 4.969952703453466, 5.294230392648275, 8.261476494856474, 4.578084062757808, 2.4057765937843394, 6.873710670356969, 1.638320123003279, 4.664899303335548, 1.7331108104638415, 3.0017836239105464, 7.80003599602104, 15.114574592062082, 11.232680148872241, 10.005622994740852, 6.677265768361006, 8.083651139780414, 3.095125488505785, 6.437713764093826, 3.893420245785277, 14.694246473235717, 5.037659891739701, 7.626802705451098, 2.5241438339563493, 5.904864883608947, 7.843812403707738, 12.497969724896604, 10.019434368241056, 9.912385327698678, 3.5056375043841954, 9.727451833966871, 7.055470935128648, 4.0524551643749716, 1.879730655482965, 8.566622801797541, 6.870719622945782, 6.805222866473522, 7.5945917090467265, 4.479689059637344, 1.7476032610313146, 12.012554535110098, 4.344727037097035, 5.1475183658371275, 4.929247595289706, 2.9767016091855814, 3.8013052386196087, 5.163068857618053, 5.169016219493707, 0.23193458642913495, 8.70587864640201, 10.939132784889937, 11.714469697769426, 7.083753784056498, 11.87326902051134, 7.042338844026588, 5.017503913172917, 4.778864606772573, 3.042887706733667, 3.6620003736411966, 2.743270040816711, 3.109538682661215, 3.47122843715454, 0.9270974763853952, 3.1363274047025853, 3.2824426459231435, 3.9788310114108043, 4.111546401232696, 5.7061916064139915, 6.584877096878639, 3.5742826272280923, 4.703240912706944, 7.070766637930972, 4.95580073560926, 1.113246997898117, 3.7917324628472677, 7.635317270006105, 7.265776971711405, 8.08894883562896, 9.30857811446153, 8.481931382649236, 8.390060660855669, 2.780535203554567, 6.981771051385416, 6.078309168487301, 4.051853929900172, 2.8821069096573844, 1.3148482131162407, 9.204216979484197, 11.84263453595644, 9.28439242785293, 5.036180745761245, 1.9810687269074243, 7.281151505468485, 3.7037789335909572, 8.620908849396908, 2.973269893149945, 4.962337578986062, 10.313583410463899, 4.535784026599548, 3.9355420103127057, 2.0844480324890284, 8.118925125247987, 4.774541870691803, 8.500005021588965, 4.037775224422349, 5.508435858674064, 6.158846298322687, 5.442960529579389, 1.9271087410673418, 3.1783146377949656, 0.1381220556981794, 5.034382971106375, 5.58787272180235, 7.403737489296438, 5.0487119870940464, 4.6929350815155155, 10.517043507890369, 2.5448682475593194, 8.208869345968692, 1.7587675406301824, 2.4395573289764765, 3.6057656416570687, 4.352896534449493, 6.91868977709811, 4.322284994440481, 9.784237998836684, 9.58841112899518, 1.8941175888006894, 7.583009687930468, 5.7531657246 ...

# %%
fig,ax=plt.subplots(figsize=(8,5))
chain_length=150
testeq=equil_chain_rg_ree.copy().sort_values(by='epas')
epas_cutoff=0.3
for epas in testeq.epas.unique():
    if epas<epas_cutoff:
        ax.hist(testeq[(testeq.chain_length==chain_length) & (testeq.epas==epas) ].ratio,
                label='epas= '+str(epas),
                histtype='step',linestyle=('solid'),density=False,
               bins=np.arange(testeq[(testeq.chain_length==chain_length) & (testeq.epas==epas) ].ratio.min(),
                             testeq[(testeq.chain_length==chain_length) & (testeq.epas==epas) ].ratio.max(),0.25),
               linewidth=2)
        print('Mean Ratio @ epas: ',str(epas),'\t',format(testeq[(testeq.chain_length==chain_length) & (testeq.epas==epas) ].ratio.mean(),'0.2f'))
#     elif epas in [-0.2,-0.1,0,0.2,0.4,0.6,0.8] and epas<0.4:
#         ax.hist(testeq[(testeq.chain_length==chain_length) & (testeq.epas==epas) ].sort_values(by='epas').ratio,
#                 label='epas= '+str(epas),
#                 histtype='step',linestyle=('solid'),density=False,
#                bins=np.arange(testeq[(testeq.chain_length==chain_length) & (testeq.epas==epas) ].ratio.min(),
#                              testeq[(testeq.chain_length==chain_length) & (testeq.epas==epas) ].ratio.max(),0.18),
#                linewidth=2)


ax.text(0.1,0.95,'Chain Length= '+str(chain_length)+' & all epas<'+str(epas_cutoff),transform=ax.transAxes,
        fontsize=14)
plt.legend(fontsize=13)
plt.ylabel('Frequency',fontsize=15)
plt.xlabel('Ratio <Ree^2/Rg^2>',fontsize=15)
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.xlim(0,20)
plt.tight_layout()
del testeq
# Out:
# Mean Ratio @ epas:  -0.2 	 6.03
# Mean Ratio @ epas:  -0.15 	 6.05
# Mean Ratio @ epas:  -0.1 	 6.06
# Mean Ratio @ epas:  -0.05 	 5.99
# Mean Ratio @ epas:  0.0 	 5.94
# Mean Ratio @ epas:  0.05 	 5.91
# Mean Ratio @ epas:  0.1 	 5.75
# Mean Ratio @ epas:  0.15 	 5.50
# Mean Ratio @ epas:  0.2 	 4.92
# Mean Ratio @ epas:  0.25 	 4.06

# %%
fig,ax=plt.subplots(figsize=(8,5))
chain_length=100
testeq=equil_chain_rg_ree.copy().sort_values(by='epas')
epas_cutoff=0.3
for epas in testeq.epas.unique():
    if epas<epas_cutoff:
        ax.hist(testeq[(testeq.chain_length==chain_length) & (testeq.epas==epas) ].ratio,
                label='epas= '+str(epas),
                histtype='step',linestyle=('solid'),density=False,
               bins=np.arange(testeq[(testeq.chain_length==chain_length) & (testeq.epas==epas) ].ratio.min(),
                             testeq[(testeq.chain_length==chain_length) & (testeq.epas==epas) ].ratio.max(),0.25),
               linewidth=2)
        print('Mean Ratio @ epas: ',str(epas),'\t',format(testeq[(testeq.chain_length==chain_length) & (testeq.epas==epas) ].ratio.mean(),'0.2f'))
#     elif epas in [-0.2,-0.1,0,0.2,0.4,0.6,0.8] and epas<0.4:
#         ax.hist(testeq[(testeq.chain_length==chain_length) & (testeq.epas==epas) ].sort_values(by='epas').ratio,
#                 label='epas= '+str(epas),
#                 histtype='step',linestyle=('solid'),density=False,
#                bins=np.arange(testeq[(testeq.chain_length==chain_length) & (testeq.epas==epas) ].ratio.min(),
#                              testeq[(testeq.chain_length==chain_length) & (testeq.epas==epas) ].ratio.max(),0.18),
#                linewidth=2)


ax.text(0.1,0.95,'Chain Length= '+str(chain_length)+' & all epas<'+str(epas_cutoff),transform=ax.transAxes,
        fontsize=14)
plt.legend(fontsize=13)
plt.ylabel('Frequency',fontsize=15)
plt.xlabel('Ratio <Ree^2/Rg^2>',fontsize=15)
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.xlim(0,20)
plt.tight_layout()
del testeq
# Out:
# Mean Ratio @ epas:  -0.2 	 6.12
# Mean Ratio @ epas:  -0.15 	 6.09
# Mean Ratio @ epas:  -0.1 	 6.04
# Mean Ratio @ epas:  -0.05 	 6.00
# Mean Ratio @ epas:  0.0 	 5.97
# Mean Ratio @ epas:  0.05 	 5.86
# Mean Ratio @ epas:  0.1 	 5.75
# Mean Ratio @ epas:  0.15 	 5.51
# Mean Ratio @ epas:  0.2 	 5.08
# Mean Ratio @ epas:  0.25 	 4.40

# %%
fig,ax=plt.subplots(figsize=(8,5))
chain_length=50
testeq=equil_chain_rg_ree.copy().sort_values(by='epas')
epas_cutoff=0.3
for epas in testeq.epas.unique():
    if epas<epas_cutoff:
        ax.hist(testeq[(testeq.chain_length==chain_length) & (testeq.epas==epas) ].ratio,
                label='epas= '+str(epas),
                histtype='step',linestyle=('solid'),density=False,
               bins=np.arange(testeq[(testeq.chain_length==chain_length) & (testeq.epas==epas) ].ratio.min(),
                             testeq[(testeq.chain_length==chain_length) & (testeq.epas==epas) ].ratio.max(),0.25),
               linewidth=2)
        print('Mean Ratio @ epas: ',str(epas),'\t',format(testeq[(testeq.chain_length==chain_length) & (testeq.epas==epas) ].ratio.mean(),'0.2f'))
#     elif epas in [-0.2,-0.1,0,0.2,0.4,0.6,0.8] and epas<0.4:
#         ax.hist(testeq[(testeq.chain_length==chain_length) & (testeq.epas==epas) ].sort_values(by='epas').ratio,
#                 label='epas= '+str(epas),
#                 histtype='step',linestyle=('solid'),density=False,
#                bins=np.arange(testeq[(testeq.chain_length==chain_length) & (testeq.epas==epas) ].ratio.min(),
#                              testeq[(testeq.chain_length==chain_length) & (testeq.epas==epas) ].ratio.max(),0.18),
#                linewidth=2)


ax.text(0.1,0.95,'Chain Length= '+str(chain_length)+' & all epas<'+str(epas_cutoff),transform=ax.transAxes,
        fontsize=14)
plt.legend(fontsize=13)
plt.ylabel('Frequency',fontsize=15)
plt.xlabel('Ratio <Ree^2/Rg^2>',fontsize=15)
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.xlim(0,20)
plt.tight_layout()
del testeq
# Out:
# Mean Ratio @ epas:  -0.2 	 6.12
# Mean Ratio @ epas:  -0.15 	 6.11
# Mean Ratio @ epas:  -0.1 	 6.06
# Mean Ratio @ epas:  -0.05 	 6.02
# Mean Ratio @ epas:  0.0 	 5.93
# Mean Ratio @ epas:  0.05 	 5.89
# Mean Ratio @ epas:  0.1 	 5.70
# Mean Ratio @ epas:  0.15 	 5.53
# Mean Ratio @ epas:  0.2 	 5.22
# Mean Ratio @ epas:  0.25 	 4.82

# %%
fig,ax=plt.subplots(figsize=(8,5))
chain_length=150
testeq=equil_chain_rg_ree.copy().sort_values(by='epas')
epas_cutoff=0.3
for epas in testeq.epas.unique():
    if epas>=epas_cutoff:
        ax.hist(testeq[(testeq.chain_length==chain_length) & (testeq.epas==epas) ].ratio,
                label='epas= '+str(epas),
                histtype='step',linestyle=('solid'),density=False,
               bins=np.arange(testeq[(testeq.chain_length==chain_length) & (testeq.epas==epas) ].ratio.min(),
                             testeq[(testeq.chain_length==chain_length) & (testeq.epas==epas) ].ratio.max(),0.08),
               linewidth=2)
        print('Mean Ratio @ epas: ',str(epas),'\t',format(testeq[(testeq.chain_length==chain_length) & (testeq.epas==epas) ].ratio.mean(),'0.2f'))



ax.text(0.1,0.95,'Chain Length= '+str(chain_length)+' & all epas>='+str(epas_cutoff),transform=ax.transAxes,
        fontsize=14)
plt.legend(fontsize=13)
plt.ylabel('Frequency',fontsize=15)
plt.xlabel('Ratio <Ree^2/Rg^2>',fontsize=15)
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.xlim(0,20)
plt.tight_layout()
del testeq
# Out:
# Mean Ratio @ epas:  0.3 	 3.48
# Mean Ratio @ epas:  0.35 	 3.11
# Mean Ratio @ epas:  0.4 	 2.93
# Mean Ratio @ epas:  0.5 	 2.65
# Mean Ratio @ epas:  0.6 	 2.52
# Mean Ratio @ epas:  0.7 	 2.45
# Mean Ratio @ epas:  0.8 	 2.38

# %%
fig,ax=plt.subplots(figsize=(8,5))
chain_length=100
testeq=equil_chain_rg_ree.copy().sort_values(by='epas')
epas_cutoff=0.3
for epas in testeq.epas.unique():
    if epas>=epas_cutoff:
        ax.hist(testeq[(testeq.chain_length==chain_length) & (testeq.epas==epas) ].ratio,
                label='epas= '+str(epas),
                histtype='step',linestyle=('solid'),density=False,
               bins=np.arange(testeq[(testeq.chain_length==chain_length) & (testeq.epas==epas) ].ratio.min(),
                             testeq[(testeq.chain_length==chain_length) & (testeq.epas==epas) ].ratio.max(),0.08),
               linewidth=2)
        print('Mean Ratio @ epas: ',str(epas),'\t',format(testeq[(testeq.chain_length==chain_length) & (testeq.epas==epas) ].ratio.mean(),'0.2f'))



ax.text(0.1,0.95,'Chain Length= '+str(chain_length)+' & all epas>='+str(epas_cutoff),transform=ax.transAxes,
        fontsize=14)
plt.legend(fontsize=13)
plt.ylabel('Frequency',fontsize=15)
plt.xlabel('Ratio <Ree^2/Rg^2>',fontsize=15)
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.xlim(0,20)
plt.tight_layout()
del testeq
# Out:
# Mean Ratio @ epas:  0.3 	 3.78
# Mean Ratio @ epas:  0.35 	 3.40
# Mean Ratio @ epas:  0.4 	 3.11
# Mean Ratio @ epas:  0.5 	 2.82
# Mean Ratio @ epas:  0.6 	 2.65
# Mean Ratio @ epas:  0.7 	 2.52
# Mean Ratio @ epas:  0.8 	 2.44

# %%
fig,ax=plt.subplots(figsize=(8,5))
chain_length=50
testeq=equil_chain_rg_ree.copy().sort_values(by='epas')
epas_cutoff=0.3
for epas in testeq.epas.unique():
    if epas>=epas_cutoff:
        ax.hist(testeq[(testeq.chain_length==chain_length) & (testeq.epas==epas) ].ratio,
                label='epas= '+str(epas),
                histtype='step',linestyle=('solid'),density=False,
               bins=np.arange(testeq[(testeq.chain_length==chain_length) & (testeq.epas==epas) ].ratio.min(),
                             testeq[(testeq.chain_length==chain_length) & (testeq.epas==epas) ].ratio.max(),0.08),
               linewidth=2)
        print('Mean Ratio @ epas: ',str(epas),'\t',format(testeq[(testeq.chain_length==chain_length) & (testeq.epas==epas) ].ratio.mean(),'0.2f'))



ax.text(0.1,0.95,'Chain Length= '+str(chain_length)+' & all epas>='+str(epas_cutoff),transform=ax.transAxes,
        fontsize=14)
plt.legend(fontsize=13)
plt.ylabel('Frequency',fontsize=15)
plt.xlabel('Ratio <Ree^2/Rg^2>',fontsize=15)
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.xlim(0,20)
plt.tight_layout()
del testeq
# Out:
# Mean Ratio @ epas:  0.3 	 4.32
# Mean Ratio @ epas:  0.35 	 3.91
# Mean Ratio @ epas:  0.4 	 3.60
# Mean Ratio @ epas:  0.5 	 3.14
# Mean Ratio @ epas:  0.6 	 2.88
# Mean Ratio @ epas:  0.7 	 2.71
# Mean Ratio @ epas:  0.8 	 2.60

# %%
fig,ax=plt.subplots(figsize=(8,5))
chain_length=150
testeq=equil_chain_rg_ree.copy()
epas_cutoff=0.2
single_epas=0.8
for epas in testeq.epas.unique():
    if epas>=epas_cutoff and epas in [single_epas]:
        ax.hist(testeq[(testeq.chain_length==chain_length) & (testeq.epas==epas) ].ratio,
                label='epas= '+str(epas),
                histtype='step',linestyle=('solid'),density=False,
               bins=np.arange(testeq[(testeq.chain_length==chain_length) & (testeq.epas==epas) ].ratio.min(),
                             testeq[(testeq.chain_length==chain_length) & (testeq.epas==epas) ].ratio.max(),0.08),
               linewidth=2)
#     elif epas in [-0.2,-0.1,0,0.2,0.4,0.6,0.8] and epas<0.4:
#         ax.hist(testeq[(testeq.chain_length==chain_length) & (testeq.epas==epas) ].ratio,
#                 label='epas= '+str(epas),
#                 histtype='step',linestyle=('solid'),density=False,
#                bins=np.arange(testeq[(testeq.chain_length==chain_length) & (testeq.epas==epas) ].ratio.min(),
#                              testeq[(testeq.chain_length==chain_length) & (testeq.epas==epas) ].ratio.max(),0.18),
#                linewidth=2)


ax.text(0.2,0.95,'Chain Length= '+str(chain_length)+' & epas= '+str(single_epas),transform=ax.transAxes,
        fontsize=14)
plt.legend(fontsize=13)
plt.ylabel('Frequency',fontsize=15)
plt.xlabel('Ratio <Ree^2/Rg^2>',fontsize=15)
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.xlim(0,20)
plt.tight_layout()
del testeq

# %%
fig,ax=plt.subplots(figsize=(8,5))
chain_length=100
testeq=equil_chain_rg_ree.copy()
epas_cutoff=0.3
for epas in testeq.epas.unique():
    if epas<epas_cutoff:
        ax.hist(testeq[(testeq.chain_length==chain_length) & (testeq.epas==epas) ].RSA,
                label='epas= '+str(epas),
                histtype='step',linestyle=('solid'),density=False,
               bins=np.arange(testeq[(testeq.chain_length==chain_length) & (testeq.epas==epas) ].RSA.min(),
                             testeq[(testeq.chain_length==chain_length) & (testeq.epas==epas) ].RSA.max(),0.008),
               linewidth=2)
#     elif epas in [-0.2,-0.1,0,0.2,0.4,0.6,0.8] and epas<0.4:
#         ax.hist(testeq[(testeq.chain_length==chain_length) & (testeq.epas==epas) ].RSA,
#                 label='epas= '+str(epas),
#                 histtype='step',linestyle=('solid'),density=False,
#                bins=np.arange(testeq[(testeq.chain_length==chain_length) & (testeq.epas==epas) ].RSA.min(),
#                              testeq[(testeq.chain_length==chain_length) & (testeq.epas==epas) ].RSA.max(),0.18),
#                linewidth=2)


ax.text(0.05,0.95,'Chain Length= '+str(chain_length)+' & all epas<'+str(epas_cutoff),transform=ax.transAxes,
        fontsize=14)
plt.legend(fontsize=13)
plt.ylabel('Frequency',fontsize=15)
plt.xlabel('RSA',fontsize=15)
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
#plt.xlim(0,20)
plt.tight_layout()
del testeq

# %%
fig,ax=plt.subplots(figsize=(8,5))
chain_length=100
testeq=equil_chain_rg_ree.copy()
epas_cutoff=0.3
for epas in testeq.epas.unique():
    if epas>=epas_cutoff:
        ax.hist(testeq[(testeq.chain_length==chain_length) & (testeq.epas==epas) ].RSA,
                label='epas= '+str(epas),
                histtype='step',linestyle=('solid'),density=False,
               bins=np.arange(testeq[(testeq.chain_length==chain_length) & (testeq.epas==epas) ].RSA.min(),
                             testeq[(testeq.chain_length==chain_length) & (testeq.epas==epas) ].RSA.max(),0.005),
               linewidth=2)
#     elif epas in [-0.2,-0.1,0,0.2,0.4,0.6,0.8] and epas<0.4:
#         ax.hist(testeq[(testeq.chain_length==chain_length) & (testeq.epas==epas) ].RSA,
#                 label='epas= '+str(epas),
#                 histtype='step',linestyle=('solid'),density=False,
#                bins=np.arange(testeq[(testeq.chain_length==chain_length) & (testeq.epas==epas) ].RSA.min(),
#                              testeq[(testeq.chain_length==chain_length) & (testeq.epas==epas) ].RSA.max(),0.18),
#                linewidth=2)


ax.text(0.05,0.95,'Chain Length= '+str(chain_length)+' & all epas>='+str(epas_cutoff),transform=ax.transAxes,
        fontsize=14)
plt.legend(fontsize=13)
plt.ylabel('Frequency',fontsize=15)
plt.xlabel('RSA',fontsize=15)
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
#plt.xlim(0,20)
plt.tight_layout()
del testeq

# %%
fig,ax=plt.subplots(figsize=(8,5))
chain_length=100
every_jth_frame=1
testeq=equil_chain_rg_ree.sort_values(by='epas').copy()[::every_jth_frame]
epas_cutoff=0.3
for epas in testeq.epas.unique():
    if epas<epas_cutoff:
        ax.hist(testeq[(testeq.chain_length==chain_length) & (testeq.epas==epas) ].Rg2,
                label='epas= '+str(epas),
                histtype='step',linestyle=('solid'),density=False,
               bins=np.arange(testeq[(testeq.chain_length==chain_length) & (testeq.epas==epas) ].Rg2.min(),
                             testeq[(testeq.chain_length==chain_length) & (testeq.epas==epas) ].Rg2.max(),1),
               linewidth=2)
#     elif epas in [-0.2,-0.1,0,0.2,0.4,0.6,0.8] and epas<0.4:
#         ax.hist(testeq[(testeq.chain_length==chain_length) & (testeq.epas==epas) ].Rg2,
#                 label='epas= '+str(epas),
#                 histtype='step',linestyle=('solid'),density=False,
#                bins=np.arange(testeq[(testeq.chain_length==chain_length) & (testeq.epas==epas) ].Rg2.min(),
#                              testeq[(testeq.chain_length==chain_length) & (testeq.epas==epas) ].Rg2.max(),0.18),
#                linewidth=2)


ax.text(0.05,0.95,'Chain Length= '+str(chain_length)+' & all epas<'+str(epas_cutoff),transform=ax.transAxes,
        fontsize=14)
plt.legend(fontsize=13)
plt.ylabel('Frequency',fontsize=15)
plt.xlabel('Rg2',fontsize=15)
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
#plt.xlim(0,20)
plt.tight_layout()
del testeq

# %%
fig,ax=plt.subplots(figsize=(8,5))
#chain_length=50
every_jth_frame=1
testeq=equil_chain_rg_ree.copy()[::every_jth_frame]
epas=0
for chain_length in testeq.chain_length.unique():
    if epas<epas_cutoff:
        ax.hist(testeq[(testeq.chain_length==chain_length) & (testeq.epas==epas) ].Rg2**0.5/testeq[(testeq.chain_length==chain_length) & (testeq.epas==epas) ].Rg2.mean()**0.5,
                label='chain_length= '+str(chain_length),
                histtype='step',linestyle=('solid'),density=False,
               bins=np.arange(testeq[(testeq.chain_length==chain_length) & (testeq.epas==epas) ].Rg2.min()**0.5/testeq[(testeq.chain_length==chain_length) & (testeq.epas==epas) ].Rg2.mean()**0.5,
                             testeq[(testeq.chain_length==chain_length) & (testeq.epas==epas) ].Rg2.max()**0.5/testeq[(testeq.chain_length==chain_length) & (testeq.epas==epas) ].Rg2.mean()**0.5,0.01),
               linewidth=2)
        print((testeq[(testeq.chain_length==chain_length) & (testeq.epas==epas) ].Rg2**0.5/testeq[(testeq.chain_length==chain_length) & (testeq.epas==epas) ].Rg2.mean()**0.5).mean())
#     elif epas in [-0.2,-0.1,0,0.2,0.4,0.6,0.8] and epas<0.4:
#         ax.hist(testeq[(testeq.chain_length==chain_length) & (testeq.epas==epas) ].sort_values(by='epas').ratio,
#                 label='epas= '+str(epas),
#                 histtype='step',linestyle=('solid'),density=False,
#                bins=np.arange(testeq[(testeq.chain_length==chain_length) & (testeq.epas==epas) ].ratio.min(),
#                              testeq[(testeq.chain_length==chain_length) & (testeq.epas==epas) ].ratio.max(),0.18),
#                linewidth=2)


ax.text(0.05,0.95,'epas= '+str(epas),transform=ax.transAxes,
        fontsize=14)
plt.legend(fontsize=13)
plt.ylabel('Frequency',fontsize=15)
plt.xlabel('Rg/Rg_mean',fontsize=15)
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
#plt.xlim(0,20)
plt.tight_layout()
del testeq
# Out:
# 0.9837828104137882
# 0.9819387666050587
# 0.9810148494381631
# 0.9809132883499337
# 0.9806203241891099
# 0.9801735866705836

# %%
fig,ax=plt.subplots(figsize=(8,5))
#chain_length=50
every_jth_frame=1
testeq=equil_chain_rg_ree.copy()[::every_jth_frame]
epas=0.1
for chain_length in testeq.chain_length.unique():
    if epas>epas_cutoff:
        ax.hist(testeq[(testeq.chain_length==chain_length) & (testeq.epas==epas) ].Rg2**0.5/testeq[(testeq.chain_length==chain_length) & (testeq.epas==epas) ].Rg2.mean()**0.5,
                label='chain_length= '+str(chain_length),
                histtype='step',linestyle=('solid'),density=False,
               bins=np.arange(testeq[(testeq.chain_length==chain_length) & (testeq.epas==epas) ].Rg2.min()**0.5/testeq[(testeq.chain_length==chain_length) & (testeq.epas==epas) ].Rg2.mean()**0.5,
                             testeq[(testeq.chain_length==chain_length) & (testeq.epas==epas) ].Rg2.max()**0.5/testeq[(testeq.chain_length==chain_length) & (testeq.epas==epas) ].Rg2.mean()**0.5,0.01),
               linewidth=2)
        print((testeq[(testeq.chain_length==chain_length) & (testeq.epas==epas) ].Rg2**0.5/testeq[(testeq.chain_length==chain_length) & (testeq.epas==epas) ].Rg2.mean()**0.5).mean())
#     elif epas in [-0.2,-0.1,0,0.2,0.4,0.6,0.8] and epas<0.4:
#         ax.hist(testeq[(testeq.chain_length==chain_length) & (testeq.epas==epas) ].sort_values(by='epas').ratio,
#                 label='epas= '+str(epas),
#                 histtype='step',linestyle=('solid'),density=False,
#                bins=np.arange(testeq[(testeq.chain_length==chain_length) & (testeq.epas==epas) ].ratio.min(),
#                              testeq[(testeq.chain_length==chain_length) & (testeq.epas==epas) ].ratio.max(),0.18),
#                linewidth=2)


ax.text(0.05,0.95,'epas= '+str(epas),transform=ax.transAxes,
        fontsize=14)
plt.legend(fontsize=13)
plt.ylabel('Frequency',fontsize=15)
plt.xlabel('Rg/Rg_mean',fontsize=15)
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
#plt.xlim(0,20)
plt.tight_layout()
del testeq
# Out:
# 0.9818034056769933
# 0.9794577907599615
# 0.9784529648043085
# 0.9781120712902216
# 0.9781459060739883
# 0.9779528562503012

# %%
fig,ax=plt.subplots(figsize=(8,5))
#chain_length=50
every_jth_frame=1
testeq=equil_chain_rg_ree.copy()[::every_jth_frame]
epas=0.2
for chain_length in testeq.chain_length.unique():
    if epas>epas_cutoff:
        ax.hist(testeq[(testeq.chain_length==chain_length) & (testeq.epas==epas) ].Rg2**0.5/testeq[(testeq.chain_length==chain_length) & (testeq.epas==epas) ].Rg2.mean()**0.5,
                label='chain_length= '+str(chain_length),
                histtype='step',linestyle=('solid'),density=False,
               bins=np.arange(testeq[(testeq.chain_length==chain_length) & (testeq.epas==epas) ].Rg2.min()**0.5/testeq[(testeq.chain_length==chain_length) & (testeq.epas==epas) ].Rg2.mean()**0.5,
                             testeq[(testeq.chain_length==chain_length) & (testeq.epas==epas) ].Rg2.max()**0.5/testeq[(testeq.chain_length==chain_length) & (testeq.epas==epas) ].Rg2.mean()**0.5,0.01),
               linewidth=2)
        print((testeq[(testeq.chain_length==chain_length) & (testeq.epas==epas) ].Rg2**0.5/testeq[(testeq.chain_length==chain_length) & (testeq.epas==epas) ].Rg2.mean()**0.5).mean())
#     elif epas in [-0.2,-0.1,0,0.2,0.4,0.6,0.8] and epas<0.4:
#         ax.hist(testeq[(testeq.chain_length==chain_length) & (testeq.epas==epas) ].sort_values(by='epas').ratio,
#                 label='epas= '+str(epas),
#                 histtype='step',linestyle=('solid'),density=False,
#                bins=np.arange(testeq[(testeq.chain_length==chain_length) & (testeq.epas==epas) ].ratio.min(),
#                              testeq[(testeq.chain_length==chain_length) & (testeq.epas==epas) ].ratio.max(),0.18),
#                linewidth=2)


ax.text(0.05,0.95,'epas= '+str(epas),transform=ax.transAxes,
        fontsize=14)
plt.legend(fontsize=13)
plt.ylabel('Frequency',fontsize=15)
plt.xlabel('Rg/Rg_mean',fontsize=15)
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
#plt.xlim(0,20)
plt.tight_layout()
del testeq
# Out:
# 0.98045046037244
# 0.9765712831291538
# 0.9752197548954787
# 0.9735910486152476
# 0.9731480882041222
# 0.9729174039975121

# %%
fig,ax=plt.subplots(figsize=(8,5))
#chain_length=50
every_jth_frame=1
testeq=equil_chain_rg_ree.copy()[::every_jth_frame]
epas=0.25
for chain_length in testeq.chain_length.unique():
    if epas>epas_cutoff:
        ax.hist(testeq[(testeq.chain_length==chain_length) & (testeq.epas==epas) ].Rg2**0.5/testeq[(testeq.chain_length==chain_length) & (testeq.epas==epas) ].Rg2.mean()**0.5,
                label='chain_length= '+str(chain_length),
                histtype='step',linestyle=('solid'),density=False,
               bins=np.arange(testeq[(testeq.chain_length==chain_length) & (testeq.epas==epas) ].Rg2.min()**0.5/testeq[(testeq.chain_length==chain_length) & (testeq.epas==epas) ].Rg2.mean()**0.5,
                             testeq[(testeq.chain_length==chain_length) & (testeq.epas==epas) ].Rg2.max()**0.5/testeq[(testeq.chain_length==chain_length) & (testeq.epas==epas) ].Rg2.mean()**0.5,0.01),
               linewidth=2)
        print((testeq[(testeq.chain_length==chain_length) & (testeq.epas==epas) ].Rg2**0.5/testeq[(testeq.chain_length==chain_length) & (testeq.epas==epas) ].Rg2.mean()**0.5).mean())
#     elif epas in [-0.2,-0.1,0,0.2,0.4,0.6,0.8] and epas<0.4:
#         ax.hist(testeq[(testeq.chain_length==chain_length) & (testeq.epas==epas) ].sort_values(by='epas').ratio,
#                 label='epas= '+str(epas),
#                 histtype='step',linestyle=('solid'),density=False,
#                bins=np.arange(testeq[(testeq.chain_length==chain_length) & (testeq.epas==epas) ].ratio.min(),
#                              testeq[(testeq.chain_length==chain_length) & (testeq.epas==epas) ].ratio.max(),0.18),
#                linewidth=2)


ax.text(0.05,0.95,'epas= '+str(epas),transform=ax.transAxes,
        fontsize=14)
plt.legend(fontsize=13)
plt.ylabel('Frequency',fontsize=15)
plt.xlabel('Rg/Rg_mean',fontsize=15)
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
#plt.xlim(0,20)
plt.tight_layout()
del testeq
# Out:
# 0.9801951350058955
# 0.9781330030218743
# 0.978472397576019
# 0.980644259430877
# 0.9837089551692905
# 0.9865980916306321

# %%
fig,ax=plt.subplots(figsize=(8,5))
#chain_length=50
every_jth_frame=1
testeq=equil_chain_rg_ree.copy()[::every_jth_frame]
epas=0.1
for chain_length in testeq.chain_length.unique():
    if epas>epas_cutoff:
        ax.hist(testeq[(testeq.chain_length==chain_length) & (testeq.epas==epas) ].ratio,
                label='chain_length= '+str(chain_length),
                histtype='step',linestyle=('solid'),density=False,
               bins=np.arange(testeq[(testeq.chain_length==chain_length) & (testeq.epas==epas) ].ratio.min(),
                             testeq[(testeq.chain_length==chain_length) & (testeq.epas==epas) ].ratio.max(),0.15),
               linewidth=2)
        print(testeq[(testeq.chain_length==chain_length) & (testeq.epas==epas) ].ratio.mean())
#     elif epas in [-0.2,-0.1,0,0.2,0.4,0.6,0.8] and epas<0.4:
#         ax.hist(testeq[(testeq.chain_length==chain_length) & (testeq.epas==epas) ].sort_values(by='epas').ratio,
#                 label='epas= '+str(epas),
#                 histtype='step',linestyle=('solid'),density=False,
#                bins=np.arange(testeq[(testeq.chain_length==chain_length) & (testeq.epas==epas) ].ratio.min(),
#                              testeq[(testeq.chain_length==chain_length) & (testeq.epas==epas) ].ratio.max(),0.18),
#                linewidth=2)


ax.text(0.05,0.95,'epas= '+str(epas),transform=ax.transAxes,
        fontsize=14)
plt.legend(fontsize=13)
plt.ylabel('Frequency',fontsize=15)
plt.xlabel('Ratio <Ree^2/Rg^2>',fontsize=15)
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.xlim(0,20)
plt.tight_layout()
del testeq
# Out:
# 5.671877936163933
# 5.7013859231261685
# 5.75399911448874
# 5.749449681100925
# 5.76603318848511
# 5.74616559836544

# %%
fig,ax=plt.subplots(figsize=(8,5))
#chain_length=50
every_jth_frame=1
testeq=equil_chain_rg_ree.copy()[::every_jth_frame]
epas=0.2
for chain_length in testeq.chain_length.unique():
    if epas>epas_cutoff:
        ax.hist(testeq[(testeq.chain_length==chain_length) & (testeq.epas==epas) ].ratio,
                label='chain_length= '+str(chain_length),
                histtype='step',linestyle=('solid'),density=False,
               bins=np.arange(testeq[(testeq.chain_length==chain_length) & (testeq.epas==epas) ].ratio.min(),
                             testeq[(testeq.chain_length==chain_length) & (testeq.epas==epas) ].ratio.max(),0.15),
               linewidth=2)
        print(testeq[(testeq.chain_length==chain_length) & (testeq.epas==epas) ].ratio.mean())
#     elif epas in [-0.2,-0.1,0,0.2,0.4,0.6,0.8] and epas<0.4:
#         ax.hist(testeq[(testeq.chain_length==chain_length) & (testeq.epas==epas) ].sort_values(by='epas').ratio,
#                 label='epas= '+str(epas),
#                 histtype='step',linestyle=('solid'),density=False,
#                bins=np.arange(testeq[(testeq.chain_length==chain_length) & (testeq.epas==epas) ].ratio.min(),
#                              testeq[(testeq.chain_length==chain_length) & (testeq.epas==epas) ].ratio.max(),0.18),
#                linewidth=2)


ax.text(0.05,0.95,'epas= '+str(epas),transform=ax.transAxes,
        fontsize=14)
plt.legend(fontsize=13)
plt.ylabel('Frequency',fontsize=15)
plt.xlabel('Ratio <Ree^2/Rg^2>',fontsize=15)
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.xlim(0,20)
plt.tight_layout()
del testeq
# Out:
# 5.305102063062479
# 5.221269680807487
# 5.182067953478299
# 5.07965478541982
# 4.984521294213834
# 4.918120420639523

# %%
fig,ax=plt.subplots(figsize=(8,5))
#chain_length=50
every_jth_frame=1
testeq=equil_chain_rg_ree.copy()[::every_jth_frame]
epas=0.25
for chain_length in testeq.chain_length.unique():
    if epas>epas_cutoff:
        ax.hist(testeq[(testeq.chain_length==chain_length) & (testeq.epas==epas) ].ratio,
                label='chain_length= '+str(chain_length),
                histtype='step',linestyle=('solid'),density=False,
               bins=np.arange(testeq[(testeq.chain_length==chain_length) & (testeq.epas==epas) ].ratio.min(),
                             testeq[(testeq.chain_length==chain_length) & (testeq.epas==epas) ].ratio.max(),0.15),
               linewidth=2)
        print(testeq[(testeq.chain_length==chain_length) & (testeq.epas==epas) ].ratio.mean())
#     elif epas in [-0.2,-0.1,0,0.2,0.4,0.6,0.8] and epas<0.4:
#         ax.hist(testeq[(testeq.chain_length==chain_length) & (testeq.epas==epas) ].sort_values(by='epas').ratio,
#                 label='epas= '+str(epas),
#                 histtype='step',linestyle=('solid'),density=False,
#                bins=np.arange(testeq[(testeq.chain_length==chain_length) & (testeq.epas==epas) ].ratio.min(),
#                              testeq[(testeq.chain_length==chain_length) & (testeq.epas==epas) ].ratio.max(),0.18),
#                linewidth=2)


ax.text(0.05,0.95,'epas= '+str(epas),transform=ax.transAxes,
        fontsize=14)
plt.legend(fontsize=13)
plt.ylabel('Frequency',fontsize=15)
plt.xlabel('Ratio <Ree^2/Rg^2>',fontsize=15)
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.xlim(0,20)
plt.tight_layout()
del testeq
# Out:
# 5.037130523630654
# 4.824628459555273
# 4.601479282128995
# 4.3970346008362675
# 4.243759167184875
# 4.064430790968167

# %%
fig,ax=plt.subplots(figsize=(8,5))
#chain_length=50
testeq=equil_chain_rg_ree.copy()
epas=0
for chain_length in testeq.chain_length.unique():
    if epas<epas_cutoff:
        ax.hist(testeq[(testeq.chain_length==chain_length) & (testeq.epas==epas) ].ratio,
                label='chain_length= '+str(chain_length),
                histtype='step',linestyle=('solid'),density=False,
               bins=np.arange(testeq[(testeq.chain_length==chain_length) & (testeq.epas==epas) ].ratio.min(),
                             testeq[(testeq.chain_length==chain_length) & (testeq.epas==epas) ].ratio.max(),0.25),
               linewidth=2)
        print('Mean Ratio ',format(testeq[(testeq.chain_length==chain_length) & (testeq.epas==epas) ].ratio.mean(),'0.2f'))
#     elif epas in [-0.2,-0.1,0,0.2,0.4,0.6,0.8] and epas<0.4:
#         ax.hist(testeq[(testeq.chain_length==chain_length) & (testeq.epas==epas) ].sort_values(by='epas').ratio,
#                 label='epas= '+str(epas),
#                 histtype='step',linestyle=('solid'),density=False,
#                bins=np.arange(testeq[(testeq.chain_length==chain_length) & (testeq.epas==epas) ].ratio.min(),
#                              testeq[(testeq.chain_length==chain_length) & (testeq.epas==epas) ].ratio.max(),0.18),
#                linewidth=2)


ax.text(0.05,0.95,'epas= '+str(epas),transform=ax.transAxes,
        fontsize=14)
plt.legend(fontsize=13)
plt.ylabel('Frequency',fontsize=15)
plt.xlabel('Ratio <Ree^2/Rg^2>',fontsize=15)
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.xlim(0,20)
plt.tight_layout()
del testeq
# Out:
# Mean Ratio  5.91
# Mean Ratio  5.93
# Mean Ratio  5.96
# Mean Ratio  5.97
# Mean Ratio  5.96
# Mean Ratio  5.94

# %%
fig,ax=plt.subplots(figsize=(8,5))
#chain_length=50
testeq=equil_chain_rg_ree.copy()
epas=0.2
epas_cutoff=0.3
for chain_length in testeq.chain_length.unique():
    if epas<epas_cutoff:
        ax.hist(testeq[(testeq.chain_length==chain_length) & (testeq.epas==epas) ].ratio,
                label='chain_length= '+str(chain_length),
                histtype='step',linestyle=('solid'),density=False,
               bins=np.arange(testeq[(testeq.chain_length==chain_length) & (testeq.epas==epas) ].ratio.min(),
                             testeq[(testeq.chain_length==chain_length) & (testeq.epas==epas) ].ratio.max(),0.25),
               linewidth=2)
        print('Mean Ratio ',format(testeq[(testeq.chain_length==chain_length) & (testeq.epas==epas) ].ratio.mean(),'0.2f'))
#     elif epas in [-0.2,-0.1,0,0.2,0.4,0.6,0.8] and epas<0.4:
#         ax.hist(testeq[(testeq.chain_length==chain_length) & (testeq.epas==epas) ].sort_values(by='epas').ratio,
#                 label='epas= '+str(epas),
#                 histtype='step',linestyle=('solid'),density=False,
#                bins=np.arange(testeq[(testeq.chain_length==chain_length) & (testeq.epas==epas) ].ratio.min(),
#                              testeq[(testeq.chain_length==chain_length) & (testeq.epas==epas) ].ratio.max(),0.18),
#                linewidth=2)


ax.text(0.05,0.95,'epas= '+str(epas),transform=ax.transAxes,
        fontsize=14)
plt.legend(fontsize=13)
plt.ylabel('Frequency',fontsize=15)
plt.xlabel('Ratio <Ree^2/Rg^2>',fontsize=15)
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.xlim(0,20)
plt.tight_layout()
del testeq
# Out:
# Mean Ratio  5.31
# Mean Ratio  5.22
# Mean Ratio  5.18
# Mean Ratio  5.08
# Mean Ratio  4.98
# Mean Ratio  4.92

# %%
equil_chain_rg_ree
# Out:
#         epas  chain_length        Rgx        Rgy        Rgz  Rendx  Rendy  \
# 1001   -0.05            25   8.800000   0.633600   2.000000  100.0    0.0
# 1002   -0.05            25   1.017600   5.158400   0.809600    9.0   16.0
# 1003   -0.05            25   4.320000   0.742400   1.766400   36.0    0.0
# 1004   -0.05            25   1.462400   2.486400   3.081600    1.0    4.0
# 1005   -0.05            25   0.489600   5.382400   4.640000    1.0   36.0
# ...      ...           ...        ...        ...        ...    ...    ...
# 170165  0.15           150   7.498889  10.187956   6.485556   36.0    4.0
# 170166  0.15           150   6.889956  34.403733  14.505822   25.0  225.0
# 170167  0.15           150  13.744400  15.398933   4.841956  100.0   36.0
# 170168  0.15           150   6.879822  13.436667  10.267733    0.0  144.0
# 170169  0.15           150   6.178489  17.624933   8.578489   36.0  196.0
#
#         Rendz  Rend2        Rg2     ratio  asphericity  acylindricity  \
# 1001      4.0  104.0  11.433600  9.095998     7.483200      -1.366400
# 1002      9.0   34.0   6.985600  4.867155    -1.966400       4.348800
# 1003      4.0   40.0   6.828800  5.857545     3.065600      -1.024000
# 1004     25.0   30.0   7.030400  4.267183    -1.321600      -0.595200
# 1005     25.0   62.0  10.512000  5.898021    -4.521600       0.742400
# ...       ...    ...        ...       ...          ...            ...
# 170165    1.0   41.0  24.172400  1.696149    -0.837867       3.702400
# 170166   25.0  275.0  55.799511  4.928359   -17.564822      19.897911
# 170167    9.0  145.0  33.985289  4.266552     3.623956      10.556978
# 170168    1.0  145.0  30.584222  4.741007    -4.972378       3.168933
# 170169   81.0  313.0  32.381911  9.665890    -6.923222       9.046444
#
#              RSA
# 1001    0.662625
# 1002    0.608197
# 1003    0.467328
# 1004    0.201776
# 1005    0.434464
# ...          ...
# 170165  0.137100
# 170166  0.440976
# 170167  0.289380
# 170168  0.185699
# 170169  0.322869
#
# [1148418 rows x 14 columns]

# %%
fig,ax=plt.subplots(figsize=(7,4))
chain_length=150
epas=0.8
plt.scatter(equil_chain_rg_ree[(equil_chain_rg_ree.chain_length==chain_length)&(equil_chain_rg_ree.epas==epas)].reset_index().index,
        equil_chain_rg_ree[(equil_chain_rg_ree.chain_length==chain_length)&(equil_chain_rg_ree.epas==epas)].reset_index().ratio,
           s=5)
plt.xlabel('Snapshots')
plt.ylabel('Ratio <Ree^2/Rg^2>')
ax.text(0.3,0.95,'Chain Length,epas= '+str(chain_length)+', '+str(epas),transform=ax.transAxes)
# Out:
# Text(0.3, 0.95, 'Chain Length,epas= 150, 0.8')

# %%
fig,ax=plt.subplots(figsize=(7,4))
chain_length=50
epas=0.8
plt.scatter(equil_chain_rg_ree[(equil_chain_rg_ree.chain_length==chain_length)&(equil_chain_rg_ree.epas==epas)].reset_index().index,
        equil_chain_rg_ree[(equil_chain_rg_ree.chain_length==chain_length)&(equil_chain_rg_ree.epas==epas)].reset_index().ratio,
           s=5)
plt.xlabel('Snapshots')
plt.ylabel('Ratio <Ree^2/Rg^2>')
ax.text(0.3,0.95,'Chain Length,epas= '+str(chain_length)+', '+str(epas),transform=ax.transAxes)
# Out:
# Text(0.3, 0.95, 'Chain Length,epas= 50, 0.8')

# %%
fig,ax=plt.subplots(figsize=(7,4))
chain_length=50
#epas=-0.2
for epas in equil_chain_rg_ree[equil_chain_rg_ree.chain_length==chain_length].sort_values(by='epas').epas.unique():
    if epas<0.3:
        plt.scatter(epas,
                    equil_chain_rg_ree[(equil_chain_rg_ree.chain_length==chain_length)&(equil_chain_rg_ree.epas==epas)].reset_index().ratio.max())
plt.ylabel('Max Ratio <Ree^2/Rg^2>')
plt.xlabel('epas')
ax.text(0.3,0.95,'Chain Length '+str(chain_length),transform=ax.transAxes)
# Out:
# Text(0.3, 0.95, 'Chain Length 50')

# %%
fig,ax=plt.subplots(figsize=(7,4))
chain_length=50
#epas=-0.2
for epas in equil_chain_rg_ree[equil_chain_rg_ree.chain_length==chain_length].sort_values(by='epas').epas.unique():
    if epas<0.3:
        plt.scatter(epas,
                    equil_chain_rg_ree[(equil_chain_rg_ree.chain_length==chain_length)&(equil_chain_rg_ree.epas==epas)].reset_index().ratio.min())
plt.ylabel('Min Ratio <Ree^2/Rg^2>')
plt.xlabel('epas')
ax.text(0.3,0.95,'Chain Length '+str(chain_length),transform=ax.transAxes)
# Out:
# Text(0.3, 0.95, 'Chain Length 50')

# %%
fig,ax=plt.subplots(figsize=(7,4))
chain_length=50
#epas=-0.2
for epas in equil_chain_rg_ree[equil_chain_rg_ree.chain_length==chain_length].sort_values(by='epas').epas.unique():
    if epas<0.3:
        plt.scatter(epas,
                    equil_chain_rg_ree[(equil_chain_rg_ree.chain_length==chain_length)&(equil_chain_rg_ree.epas==epas)].reset_index().ratio.mean())
plt.ylabel('Mean Ratio <Ree^2/Rg^2>')
plt.xlabel('epas')
ax.text(0.3,0.95,'Chain Length '+str(chain_length),transform=ax.transAxes)
# Out:
# Text(0.3, 0.95, 'Chain Length 50')

# %%
fig,ax=plt.subplots(figsize=(7,4))
chain_length=150
#epas=-0.2
for epas in equil_chain_rg_ree[equil_chain_rg_ree.chain_length==chain_length].sort_values(by='epas').epas.unique():
    if epas<0.3:
        plt.scatter(epas,
                    equil_chain_rg_ree[(equil_chain_rg_ree.chain_length==chain_length)&(equil_chain_rg_ree.epas==epas)].reset_index().ratio.max())
plt.ylabel('Max Ratio <Ree^2/Rg^2>')
plt.xlabel('epas')
ax.text(0.3,0.95,'Chain Length '+str(chain_length),transform=ax.transAxes)
# Out:
# Text(0.3, 0.95, 'Chain Length 150')

# %%
fig,ax=plt.subplots(figsize=(7,4))
chain_length=150
#epas=-0.2
for epas in equil_chain_rg_ree[equil_chain_rg_ree.chain_length==chain_length].sort_values(by='epas').epas.unique():
    if epas<0.3:
        plt.scatter(epas,
                    equil_chain_rg_ree[(equil_chain_rg_ree.chain_length==chain_length)&(equil_chain_rg_ree.epas==epas)].reset_index().ratio.min())
plt.ylabel('Min Ratio <Ree^2/Rg^2>')
plt.xlabel('epas')
ax.text(0.3,0.95,'Chain Length '+str(chain_length),transform=ax.transAxes)
# Out:
# Text(0.3, 0.95, 'Chain Length 150')

# %%
fig,ax=plt.subplots(figsize=(7,4))
chain_length=150
#epas=-0.2
for epas in equil_chain_rg_ree[equil_chain_rg_ree.chain_length==chain_length].sort_values(by='epas').epas.unique():
    if epas<0.3:
        plt.scatter(epas,
                    equil_chain_rg_ree[(equil_chain_rg_ree.chain_length==chain_length)&(equil_chain_rg_ree.epas==epas)].reset_index().ratio.mean())
plt.ylabel('Mean Ratio <Ree^2/Rg^2>')
plt.xlabel('epas')
ax.text(0.3,0.95,'Chain Length '+str(chain_length),transform=ax.transAxes)
# Out:
# Text(0.3, 0.95, 'Chain Length 150')

# %%
epas=-0.2
fig,ax=plt.subplots(figsize=(7,4))
for chain_length in equil_chain_rg_ree[equil_chain_rg_ree.epas==epas].chain_length.unique():
    plt.scatter(chain_length,equil_chain_rg_ree[(equil_chain_rg_ree.chain_length==chain_length)&(equil_chain_rg_ree.epas==epas)].ratio.mean(),
               label='Chain Length '+str(chain_length))
plt.xlabel('chain length')
plt.ylabel('Ratio <Ree^2/Rg^2>')
ax.text(0.3,0.95,'epas '+str(epas),transform=ax.transAxes)
# Out:
# Text(0.3, 0.95, 'epas -0.2')

# %%
epas=0.2
fig,ax=plt.subplots(figsize=(7,4))
for chain_length in equil_chain_rg_ree[equil_chain_rg_ree.epas==epas].chain_length.unique():
    plt.scatter(chain_length,equil_chain_rg_ree[(equil_chain_rg_ree.chain_length==chain_length)&(equil_chain_rg_ree.epas==epas)].ratio.mean(),
               label='Chain Length '+str(chain_length))
plt.xlabel('chain length')
plt.ylabel('Ratio <Ree^2/Rg^2>')
ax.text(0.3,0.95,'epas '+str(epas),transform=ax.transAxes)
# Out:
# Text(0.3, 0.95, 'epas 0.2')
